# %% [markdown]
# # 🥭 EXP 60 — Best_E_BS16_DU64_D3
# ## DenseNet169 | Transfer Learning (base congelada)
# > ⚡ **Google Colab** — Activar GPU: `Entorno de ejecución → Cambiar tipo → T4 GPU`
#
# | Hiperparámetro | Valor |
# |---|---|
# | Learning Rate | `5e-05` |
# | Batch Size | `16` |
# | Épocas máx. | `50` |
# | Optimizador | `Adam` |
# | Dropout | `0.3` |
# | Dense Units | `64` |
# | L2 Regularización | `1e-05` |
# | EarlyStopping patience | `10` |
# | BatchNorm cabeza | `True` |
# | Criterio mejor modelo | **F1-Score weighted** |

# %%
# !pip install -q kagglehub seaborn scikit-learn
print('✅ Paquetes instalados')
# Out:
# ✅ Paquetes instalados

# %%
import os, json, warnings, math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import pandas as pd
import tensorflow as tf
import kagglehub
from tensorflow import keras
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, Callback
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import (classification_report, confusion_matrix,
                              f1_score, precision_score, recall_score, accuracy_score)
from sklearn.utils import class_weight
warnings.filterwarnings('ignore')
print(f'TensorFlow: {tf.__version__}')
print(f'GPU: {tf.config.list_physical_devices("GPU")}')
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ─── Descarga del dataset (una sola vez) ──────────────────────────────────
kaggle_credentials = {
    'username': 'datasetdense169',
    'key': '58501601b86ccbf504958f6bff2df66b'
}
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)
with open(os.path.expanduser('~/.kaggle/kaggle.json'), 'w') as f:
    json.dump(kaggle_credentials, f)
os.chmod(os.path.expanduser('~/.kaggle/kaggle.json'), 0o600)

download_path = kagglehub.dataset_download('datasetdense169/datasetmangokent')
dataset_path  = os.path.join(download_path, 'DatasetV4_MejoraSelectiva')
train_dir = os.path.join(dataset_path, 'train')
val_dir   = os.path.join(dataset_path, 'valid')
test_dir  = os.path.join(dataset_path, 'test')

for split, path in [('train', train_dir), ('valid', val_dir), ('test', test_dir)]:
    if os.path.exists(path):
        clases = sorted([d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))])
        total  = sum(len([f for f in os.listdir(os.path.join(path, c))
                          if f.lower().endswith(('.jpg','.jpeg','.png'))]) for c in clases)
        print(f'  ✓ {split:6s}: {total:>5} imgs | clases: {clases}')
    else:
        print(f'  ✗ {split} NO encontrado')
# Out:
# Using Colab cache for faster access to the 'datasetmangokent' dataset.
#   ✓ train :  1032 imgs | clases: ['Defectuoso', 'Sanos']
#   ✓ valid :   239 imgs | clases: ['Defectuoso', 'Sanos']
#   ✓ test  :   316 imgs | clases: ['Defectuoso', 'Sanos']

# %%
# ─── Resultados de este experimento ─────────────────────────────────
RESULTS_TABLE = []  # tabla local para este experimento
print('✅ EXP 60 — Best_E_BS16_DU64_D3 — Notebook individual')
print('   Criterio de selección: F1-Score weighted en validación')
# Out:
# ✅ EXP 60 — Best_E_BS16_DU64_D3 — Notebook individual
#    Criterio de selección: F1-Score weighted en validación

# %%
# ─── Callback: Mejor modelo por F1-Score ────────────────────────────────
class BestF1Checkpoint(Callback):
    def __init__(self, val_ds, ckpt_path, verbose=1):
        super().__init__()
        self.val_ds    = val_ds
        self.ckpt_path = ckpt_path
        self.best_f1   = -1.0
        self.best_epoch = 0
        self.verbose   = verbose
        self.f1_history = []

    def on_epoch_end(self, epoch, logs=None):
        y_true, y_pred = [], []
        for x_batch, y_batch in self.val_ds:
            preds = self.model.predict(x_batch, verbose=0)
            y_true.extend(y_batch.numpy().flatten().astype(int))
            y_pred.extend((preds.flatten() > 0.5).astype(int))
        current_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
        self.f1_history.append(current_f1)
        if self.verbose:
            print(f'  val_f1_weighted: {current_f1:.4f}', end='')
        if current_f1 > self.best_f1:
            self.best_f1    = current_f1
            self.best_epoch = epoch + 1
            self.model.save_weights(self.ckpt_path)
            if self.verbose:
                print(f' ✅ Nuevo mejor F1 — pesos guardados')
        else:
            if self.verbose:
                print(f' (mejor: {self.best_f1:.4f} en época {self.best_epoch})')

    def on_train_end(self, logs=None):
        print(f'\n🏆 Mejor F1 en validación: {self.best_f1:.4f} (época {self.best_epoch})')
        print(f'   Restaurando mejores pesos...')
        self.model.load_weights(self.ckpt_path)
        print('   ✅ Pesos restaurados.')

print('✅ Callback BestF1Checkpoint definido')
# Out:
# ✅ Callback BestF1Checkpoint definido

# %%
# ─── Función de construcción del modelo (Transfer Learning puro) ──────────
def get_optimizer():
    opt = CFG['OPTIMIZER']
    lr  = CFG['LR']
    if   opt == 'Adam'        : return keras.optimizers.Adam(learning_rate=lr)
    elif opt == 'Adamax'      : return keras.optimizers.Adamax(learning_rate=lr)
    elif opt == 'SGD'         : return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    elif opt == 'SGD_Nesterov': return keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True)
    elif opt == 'RMSprop'     : return keras.optimizers.RMSprop(learning_rate=lr)
    else: raise ValueError(f'Optimizador desconocido: {opt}')

def build_model():
    base = DenseNet169(weights='imagenet', include_top=False,
                       input_shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3))
    base.trainable = False  # ← Transfer Learning puro: base CONGELADA

    inputs = keras.Input(shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3))
    x = base(inputs, training=False)
    x = GlobalAveragePooling2D(name='gap')(x)
    if CFG['BN_HEAD']:
        x = BatchNormalization(name='bn_head')(x)
    x = Dropout(CFG['DROPOUT'], name='drop1')(x)
    x = Dense(CFG['DENSE_UNITS'], activation='relu',
              kernel_regularizer=keras.regularizers.l2(CFG['L2']),
              name='dense_head')(x)
    x = Dropout(CFG['DROPOUT'] * 0.6, name='drop2')(x)
    outputs = Dense(1, activation='sigmoid', name='output')(x)

    model = Model(inputs, outputs, name=f"DenseNet169_TL_EXP{CFG['EXPERIMENT_ID']:02d}")
    model.compile(
        optimizer=get_optimizer(),
        loss='binary_crossentropy',
        metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
    )
    return model

print('✅ Función build_model definida (Transfer Learning puro)')
# Out:
# ✅ Función build_model definida (Transfer Learning puro)

# %%
# ─── Funciones de evaluación ─────────────────────────────────────────────
def evaluar(ds_prep, nombre):
    y_true, y_pred, y_prob = [], [], []
    for imgs, lbls in ds_prep:
        preds = model.predict(imgs, verbose=0)
        y_true.extend(lbls.numpy().flatten())
        y_prob.extend(preds.flatten())
        y_pred.extend((preds > 0.5).astype(int).flatten())
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)
    print(f"{'='*58}")
    print(f'  {nombre}')
    print(f"{'='*58}")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    eps = 1e-7
    loss = -np.mean(y_true * np.log(y_prob + eps) + (1 - y_true) * np.log(1 - y_prob + eps))
    return y_true, y_pred, loss

def metrics_row(y_t, yp_t, y_v, yp_v, y_te_, yp_te_):
    acc_tr  = accuracy_score(y_t,   yp_t)
    acc_va  = accuracy_score(y_v,   yp_v)
    acc_te  = accuracy_score(y_te_, yp_te_)
    prec_tr = precision_score(y_t,   yp_t,   average='weighted', zero_division=0)
    prec_va = precision_score(y_v,   yp_v,   average='weighted', zero_division=0)
    prec_te = precision_score(y_te_, yp_te_, average='weighted', zero_division=0)
    rec_tr  = recall_score(y_t,   yp_t,   average='weighted', zero_division=0)
    rec_va  = recall_score(y_v,   yp_v,   average='weighted', zero_division=0)
    rec_te  = recall_score(y_te_, yp_te_, average='weighted', zero_division=0)
    f1_tr   = f1_score(y_t,   yp_t,   average='weighted', zero_division=0)
    f1_va   = f1_score(y_v,   yp_v,   average='weighted', zero_division=0)
    f1_te   = f1_score(y_te_, yp_te_, average='weighted', zero_division=0)
    return (acc_tr,acc_va,acc_te), (prec_tr,prec_va,prec_te), \
           (rec_tr,rec_va,rec_te), (f1_tr,f1_va,f1_te)

def plot_cm(y_true, y_pred, title, ax, cmap='Blues'):
    cm_ = confusion_matrix(y_true, y_pred)
    norm = cm_.astype(float) / cm_.sum(axis=1)[:,None]
    ann  = [[f'{v}\n({p:.1%})' for v,p in zip(r,rn)] for r,rn in zip(cm_,norm)]
    sns.heatmap(cm_, annot=ann, fmt='', cmap=cmap, ax=ax,
                xticklabels=class_names, yticklabels=class_names,
                annot_kws={'size':11,'weight':'bold'})
    acc = accuracy_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred, average='weighted')
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel(f'Predicho\nAcc={acc:.4f}  F1={f1:.4f}')
    ax.set_ylabel('Real')

print('✅ Funciones de evaluación definidas')
# Out:
# ✅ Funciones de evaluación definidas

# %%
# ─── Funciones Grad-CAM ──────────────────────────────────────────────────
def get_gradcam_heatmap(img_array, model, last_conv_layer_name='conv5_block32_2_conv'):
    base_model = model.get_layer('densenet169')
    last_conv = base_model.get_layer(last_conv_layer_name)
    base_grad_model = tf.keras.models.Model(
        inputs=base_model.inputs,
        outputs=[last_conv.output, base_model.output]
    )
    img_var = tf.Variable(tf.cast(img_array, tf.float32))
    with tf.GradientTape() as tape:
        conv_outputs, base_out = base_grad_model(img_var, training=False)
        x = base_out
        for lname in ['gap', 'bn_head', 'drop1', 'dense_head', 'drop2', 'output']:
            try:
                lyr = model.get_layer(lname)
                x = lyr(x, training=False)
            except Exception:
                pass
        loss = x[:, 0]
    grads        = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap      = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap      = tf.squeeze(heatmap)
    heatmap      = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

def overlay_gradcam(original_img, heatmap, alpha=0.4):
    heatmap_resized = np.array(
        tf.image.resize(heatmap[..., np.newaxis],
                        (original_img.shape[0], original_img.shape[1]))
    ).squeeze()
    heatmap_uint8 = np.uint8(255 * heatmap_resized)
    jet_colors    = cm.get_cmap('jet')(np.arange(256))[:, :3]
    jet_heatmap   = jet_colors[heatmap_uint8]
    jet_heatmap   = np.uint8(jet_heatmap * 255)
    superimposed  = jet_heatmap * alpha + original_img * (1 - alpha)
    return np.uint8(superimposed)

print('✅ Funciones Grad-CAM definidas')
# Out:
# ✅ Funciones Grad-CAM definidas

# %%
# ─── EXP 60: Best_E_BS16_DU64_D3 ─────────────────────────────────────────────
CFG = {
    'EXPERIMENT_ID'  : 60,
    'EXPERIMENT_NAME': 'Best_E_BS16_DU64_D3',
    'DESCRIPCION'    : 'Candidato E — BS16 muy bajo LR drop30',

    # ── Rutas ──────────────────────────────────────────────────────
    'DATASET_VERSION': 'DatasetV3_Roboflow',

    # ── Imágenes ───────────────────────────────────────────────────
    'IMG_SIZE'  : 224,
    'BATCH_SIZE': 16,
    'SEED'      : 42,

    # ── Entrenamiento ──────────────────────────────────────────────
    'EPOCHS'    : 50,
    'LR'        : 5e-05,
    'OPTIMIZER' : 'Adam',
    'PATIENCE'  : 10,
    'RLR_FACTOR': 0.5,

    # ── Arquitectura del head ──────────────────────────────────────
    'DENSE_UNITS': 64,
    'DROPOUT'    : 0.3,
    'L2'         : 1e-05,
    'BN_HEAD'    : True,

    # ── Grad-CAM ──────────────────────────────────────────────────
    'GRADCAM_SAMPLES': 8,
    'GRADCAM_ALPHA'  : 0.4,
}

tf.random.set_seed(CFG['SEED'])
np.random.seed(CFG['SEED'])
os.makedirs('checkpoints', exist_ok=True)
os.makedirs('resultados',  exist_ok=True)

print('\n📋 CONFIGURACIÓN — EXP 60: Best_E_BS16_DU64_D3')
for k, v in CFG.items():
    print(f'  {k:<20}: {v}')
# Out:
# 📋 CONFIGURACIÓN — EXP 60: Best_E_BS16_DU64_D3
#   EXPERIMENT_ID       : 60
#   EXPERIMENT_NAME     : Best_E_BS16_DU64_D3
#   DESCRIPCION         : Candidato E — BS16 muy bajo LR drop30
#   DATASET_VERSION     : DatasetV3_Roboflow
#   IMG_SIZE            : 224
#   BATCH_SIZE          : 16
#   SEED                : 42
#   EPOCHS              : 50
#   LR                  : 5e-05
#   OPTIMIZER           : Adam
#   PATIENCE            : 10
#   RLR_FACTOR          : 0.5
#   DENSE_UNITS         : 64
#   DROPOUT             : 0.3
#   L2                  : 1e-05
#   BN_HEAD             : True
#   GRADCAM_SAMPLES     : 8
#   GRADCAM_ALPHA       : 0.4

# %%
# ─── EXP 60: Carga y preprocesamiento ────────────────────────────
IMG  = CFG['IMG_SIZE']
BS   = CFG['BATCH_SIZE']
SEED = CFG['SEED']

train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    train_dir, labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=True, seed=SEED)
val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    val_dir,   labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=False)
test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    test_dir,  labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=False)

class_names = train_ds_raw.class_names
preprocess_fn = tf.keras.applications.densenet.preprocess_input

def prepare(ds):
    ds = ds.map(lambda x, y: (preprocess_fn(x), y),
                num_parallel_calls=tf.data.AUTOTUNE)
    return ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds = prepare(train_ds_raw)
val_ds   = prepare(val_ds_raw)
test_ds  = prepare(test_ds_raw)

y_all = np.concatenate([y.numpy().flatten() for _, y in train_ds_raw])
cw    = class_weight.compute_class_weight('balanced', classes=np.unique(y_all), y=y_all)
class_weights_dict = dict(enumerate(cw))
print(f'Clases: {class_names}')
print(f'Pesos: { {class_names[k]: round(v,3) for k,v in class_weights_dict.items()} }')
# Out:
# Found 1032 files belonging to 2 classes.
# Found 239 files belonging to 2 classes.
# Found 316 files belonging to 2 classes.
# Clases: ['Defectuoso', 'Sanos']
# Pesos: {'Defectuoso': np.float64(1.008), 'Sanos': np.float64(0.992)}

# %%
# ─── EXP 60: Construcción del modelo ─────────────────────────────
model = build_model()
trainable = sum(tf.size(w).numpy() for w in model.trainable_weights)
total     = sum(tf.size(w).numpy() for w in model.weights)
print(f'Parámetros entrenables: {trainable:,} / {total:,} ({100*trainable/total:.2f}%)')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Parámetros entrenables: 109,953 / 12,756,161 (0.86%)

# %%
# ─── EXP 60: Entrenamiento ────────────────────────────────────────
exp_name  = f"EXP{CFG['EXPERIMENT_ID']:02d}_{CFG['EXPERIMENT_NAME']}"
ckpt_path = f"checkpoints/best_{exp_name}.weights.h5"

f1_callback = BestF1Checkpoint(val_ds, ckpt_path, verbose=1)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=CFG['PATIENCE'],
                  restore_best_weights=False, verbose=1),
    f1_callback,
    ReduceLROnPlateau(monitor='val_loss', factor=CFG['RLR_FACTOR'],
                      patience=4, min_lr=1e-8, verbose=1),
    CSVLogger(f"resultados/log_{exp_name}.csv", append=False),
]

print(f'\n=== EXPERIMENTO {CFG["EXPERIMENT_ID"]:02d}: {CFG["EXPERIMENT_NAME"]} ===')
print(f'Desc: {CFG["DESCRIPCION"]}\n')

history = model.fit(
    train_ds, epochs=CFG['EPOCHS'],
    validation_data=val_ds,
    callbacks=callbacks,
    class_weight=class_weights_dict,
    verbose=1
)

print(f'\n{"="*55}')
print(f'🏆 MEJOR ÉPOCA (F1): {f1_callback.best_epoch}')
print(f'   Mejor Val F1      : {f1_callback.best_f1:.4f}')
print(f'{"="*55}')
# Out:
# === EXPERIMENTO 60: Best_E_BS16_DU64_D3 ===
# Desc: Candidato E — BS16 muy bajo LR drop30
#
# Epoch 1/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.5545 - loss: 0.7708 - precision: 0.5434 - recall: 0.4963  val_f1_weighted: 0.8066 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.6541 - loss: 0.6420 - precision: 0.6694 - recall: 0.6192 - val_accuracy: 0.8075 - val_loss: 0.4401 - val_precision: 0.7721 - val_recall: 0.8750 - learning_rate: 5.0000e-05
# Epoch 2/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8201 - loss: 0.4250 - precision: 0.8096 - recall: 0.8281  val_f1_weighted: 0.8227 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.8266 - loss: 0.4092 - precision: 0.8163 - recall: 0.8462 - val_accuracy: 0.8243 - val_loss: 0.4027 - val_precision: 0.7746 - val_recall: 0.9167 - learning_rate: 5.0000e-05
# Epoch 3/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8640 - loss: 0.3526 - precision: 0.8306 - recall: 0.9071  val_f1_weighted: 0.8265 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - accuracy: 0.8663 - loss: 0.3446 - precision: 0.8411 - recall: 0.9058 - val_accuracy: 0.8285 - val_loss: 0.3807 - val_precision: 0.7724 - val_recall: 0.9333 - learning_rate: 5.0000e-05
# Epoch 4/50
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8738 - loss: 0.3264 - precision: 0.8378 - recall: 0.9210  val_f1_weighted: 0.8428 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.8760 - loss: 0.3187 - precision: 0.8451 - recall: 0.9231 - val_accuracy: 0.8452 - val_loss: 0.3620 - val_precision: 0.7785 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 5/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8662 - loss: 0.3179 - precision: 0.8306 - recall: 0.9127  val_f1_weighted: 0.8472 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.8682 - loss: 0.3148 - precision: 0.8368 - recall: 0.9173 - val_accuracy: 0.8494 - val_loss: 0.3447 - val_precision: 0.7838 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 6/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8907 - loss: 0.2848 - precision: 0.8483 - recall: 0.9454  val_f1_weighted: 0.8472 (mejor: 0.8472 en época 5)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.8857 - loss: 0.2948 - precision: 0.8490 - recall: 0.9404 - val_accuracy: 0.8494 - val_loss: 0.3315 - val_precision: 0.7838 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 7/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8799 - loss: 0.2894 - precision: 0.8392 - recall: 0.9332  val_f1_weighted: 0.8431 (mejor: 0.8472 en época 5)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - accuracy: 0.8837 - loss: 0.2856 - precision: 0.8472 - recall: 0.9385 - val_accuracy: 0.8452 - val_loss: 0.3184 - val_precision: 0.7823 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 8/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8842 - loss: 0.2662 - precision: 0.8466 - recall: 0.9328  val_f1_weighted: 0.8475 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.8895 - loss: 0.2630 - precision: 0.8549 - recall: 0.9404 - val_accuracy: 0.8494 - val_loss: 0.3107 - val_precision: 0.7877 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 9/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8918 - loss: 0.2629 - precision: 0.8476 - recall: 0.9492  val_f1_weighted: 0.8519 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.8992 - loss: 0.2598 - precision: 0.8636 - recall: 0.9500 - val_accuracy: 0.8536 - val_loss: 0.3035 - val_precision: 0.7931 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 10/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9025 - loss: 0.2411 - precision: 0.8534 - recall: 0.9662  val_f1_weighted: 0.8562 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.9050 - loss: 0.2469 - precision: 0.8638 - recall: 0.9635 - val_accuracy: 0.8577 - val_loss: 0.2976 - val_precision: 0.7986 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 11/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8948 - loss: 0.2300 - precision: 0.8558 - recall: 0.9440  val_f1_weighted: 0.8606 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 0.9002 - loss: 0.2372 - precision: 0.8651 - recall: 0.9500 - val_accuracy: 0.8619 - val_loss: 0.2925 - val_precision: 0.8042 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 12/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9041 - loss: 0.2225 - precision: 0.8534 - recall: 0.9708  val_f1_weighted: 0.8692 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9070 - loss: 0.2282 - precision: 0.8655 - recall: 0.9654 - val_accuracy: 0.8703 - val_loss: 0.2875 - val_precision: 0.8156 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 13/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9132 - loss: 0.2219 - precision: 0.8735 - recall: 0.9627  val_f1_weighted: 0.8735 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.9099 - loss: 0.2321 - precision: 0.8713 - recall: 0.9635 - val_accuracy: 0.8745 - val_loss: 0.2841 - val_precision: 0.8214 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 14/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9056 - loss: 0.2127 - precision: 0.8634 - recall: 0.9585  val_f1_weighted: 0.8821 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9070 - loss: 0.2140 - precision: 0.8681 - recall: 0.9615 - val_accuracy: 0.8828 - val_loss: 0.2799 - val_precision: 0.8333 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 15/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9252 - loss: 0.1999 - precision: 0.8762 - recall: 0.9860  val_f1_weighted: 0.8907 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 128ms/step - accuracy: 0.9234 - loss: 0.2073 - precision: 0.8835 - recall: 0.9769 - val_accuracy: 0.8912 - val_loss: 0.2783 - val_precision: 0.8456 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 16/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9101 - loss: 0.2015 - precision: 0.8693 - recall: 0.9604  val_f1_weighted: 0.8907 (mejor: 0.8907 en época 15)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.9157 - loss: 0.2018 - precision: 0.8778 - recall: 0.9673 - val_accuracy: 0.8912 - val_loss: 0.2765 - val_precision: 0.8456 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 17/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9257 - loss: 0.1806 - precision: 0.8862 - recall: 0.9739  val_f1_weighted: 0.8948 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9215 - loss: 0.1971 - precision: 0.8871 - recall: 0.9673 - val_accuracy: 0.8954 - val_loss: 0.2727 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 18/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9194 - loss: 0.1882 - precision: 0.8751 - recall: 0.9744  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 17)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.9234 - loss: 0.1925 - precision: 0.8875 - recall: 0.9712 - val_accuracy: 0.8954 - val_loss: 0.2712 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 19/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9260 - loss: 0.1789 - precision: 0.8896 - recall: 0.9685  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 17)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9215 - loss: 0.1889 - precision: 0.8885 - recall: 0.9654 - val_accuracy: 0.8954 - val_loss: 0.2700 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 20/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9320 - loss: 0.1767 - precision: 0.8924 - recall: 0.9786  val_f1_weighted: 0.8991 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9293 - loss: 0.1847 - precision: 0.8970 - recall: 0.9712 - val_accuracy: 0.8996 - val_loss: 0.2643 - val_precision: 0.8529 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 21/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9212 - loss: 0.1790 - precision: 0.8823 - recall: 0.9675  val_f1_weighted: 0.8991 (mejor: 0.8991 en época 20)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9254 - loss: 0.1812 - precision: 0.8948 - recall: 0.9654 - val_accuracy: 0.8996 - val_loss: 0.2630 - val_precision: 0.8529 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 22/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9260 - loss: 0.1680 - precision: 0.8778 - recall: 0.9855  val_f1_weighted: 0.8908 (mejor: 0.8991 en época 20)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 7s 105ms/step - accuracy: 0.9264 - loss: 0.1778 - precision: 0.8895 - recall: 0.9750 - val_accuracy: 0.8912 - val_loss: 0.2626 - val_precision: 0.8507 - val_recall: 0.9500 - learning_rate: 5.0000e-05
# Epoch 23/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9329 - loss: 0.1635 - precision: 0.8919 - recall: 0.9813  val_f1_weighted: 0.8951 (mejor: 0.8991 en época 20)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9341 - loss: 0.1687 - precision: 0.9021 - recall: 0.9750 - val_accuracy: 0.8954 - val_loss: 0.2609 - val_precision: 0.8571 - val_recall: 0.9500 - learning_rate: 5.0000e-05
# Epoch 24/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9462 - loss: 0.1638 - precision: 0.9141 - recall: 0.9821  val_f1_weighted: 0.9076 ✅ Nuevo mejor F1 — pesos guardados
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9448 - loss: 0.1664 - precision: 0.9156 - recall: 0.9808 - val_accuracy: 0.9079 - val_loss: 0.2597 - val_precision: 0.8657 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 25/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9461 - loss: 0.1560 - precision: 0.9145 - recall: 0.9817  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9399 - loss: 0.1620 - precision: 0.9089 - recall: 0.9788 - val_accuracy: 0.9038 - val_loss: 0.2584 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 26/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9465 - loss: 0.1457 - precision: 0.9090 - recall: 0.9897  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.9399 - loss: 0.1630 - precision: 0.9089 - recall: 0.9788 - val_accuracy: 0.9038 - val_loss: 0.2579 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 27/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9392 - loss: 0.1586 - precision: 0.9035 - recall: 0.9804  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9419 - loss: 0.1599 - precision: 0.9107 - recall: 0.9808 - val_accuracy: 0.9038 - val_loss: 0.2568 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 28/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9412 - loss: 0.1545 - precision: 0.9139 - recall: 0.9716  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9390 - loss: 0.1607 - precision: 0.9147 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2568 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 29/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9578 - loss: 0.1268 - precision: 0.9367 - recall: 0.9816  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9516 - loss: 0.1414 - precision: 0.9257 - recall: 0.9827 - val_accuracy: 0.9038 - val_loss: 0.2549 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 30/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9472 - loss: 0.1373 - precision: 0.9177 - recall: 0.9793  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9525 - loss: 0.1392 - precision: 0.9305 - recall: 0.9788 - val_accuracy: 0.9038 - val_loss: 0.2526 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 31/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9517 - loss: 0.1318 - precision: 0.9204 - recall: 0.9860  val_f1_weighted: 0.9034 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.9496 - loss: 0.1437 - precision: 0.9255 - recall: 0.9788 - val_accuracy: 0.9038 - val_loss: 0.2516 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 32/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9470 - loss: 0.1388 - precision: 0.9160 - recall: 0.9818  val_f1_weighted: 0.9076 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9419 - loss: 0.1447 - precision: 0.9167 - recall: 0.9731 - val_accuracy: 0.9079 - val_loss: 0.2502 - val_precision: 0.8657 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 33/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9557 - loss: 0.1371 - precision: 0.9292 - recall: 0.9858  val_f1_weighted: 0.9076 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9516 - loss: 0.1441 - precision: 0.9257 - recall: 0.9827 - val_accuracy: 0.9079 - val_loss: 0.2496 - val_precision: 0.8657 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 34/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9471 - loss: 0.1387 - precision: 0.9122 - recall: 0.9864  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9506 - loss: 0.1413 - precision: 0.9225 - recall: 0.9846 - val_accuracy: 0.9038 - val_loss: 0.2485 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 35/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9612 - loss: 0.1275 - precision: 0.9388 - recall: 0.9846  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.9574 - loss: 0.1355 - precision: 0.9359 - recall: 0.9827 - val_accuracy: 0.9038 - val_loss: 0.2508 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 36/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9538 - loss: 0.1225 - precision: 0.9300 - recall: 0.9807  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9535 - loss: 0.1284 - precision: 0.9322 - recall: 0.9788 - val_accuracy: 0.9038 - val_loss: 0.2512 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 37/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9587 - loss: 0.1234 - precision: 0.9332 - recall: 0.9858  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.9583 - loss: 0.1273 - precision: 0.9328 - recall: 0.9885 - val_accuracy: 0.9038 - val_loss: 0.2486 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 38/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9565 - loss: 0.1216 - precision: 0.9333 - recall: 0.9827  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9535 - loss: 0.1311 - precision: 0.9275 - recall: 0.9846 - val_accuracy: 0.9038 - val_loss: 0.2460 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 39/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9679 - loss: 0.1065 - precision: 0.9534 - recall: 0.9833  val_f1_weighted: 0.9076 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.9612 - loss: 0.1191 - precision: 0.9396 - recall: 0.9865 - val_accuracy: 0.9079 - val_loss: 0.2423 - val_precision: 0.8657 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 40/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9610 - loss: 0.1117 - precision: 0.9368 - recall: 0.9881  val_f1_weighted: 0.9076 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9583 - loss: 0.1179 - precision: 0.9360 - recall: 0.9846 - val_accuracy: 0.9079 - val_loss: 0.2416 - val_precision: 0.8657 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 41/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9566 - loss: 0.1162 - precision: 0.9433 - recall: 0.9706  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9554 - loss: 0.1237 - precision: 0.9405 - recall: 0.9731 - val_accuracy: 0.9038 - val_loss: 0.2414 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 42/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9627 - loss: 0.1084 - precision: 0.9428 - recall: 0.9845  val_f1_weighted: 0.8993 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9603 - loss: 0.1127 - precision: 0.9394 - recall: 0.9846 - val_accuracy: 0.8996 - val_loss: 0.2440 - val_precision: 0.8636 - val_recall: 0.9500 - learning_rate: 5.0000e-05
# Epoch 43/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9659 - loss: 0.1095 - precision: 0.9464 - recall: 0.9872  val_f1_weighted: 0.8993 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9603 - loss: 0.1156 - precision: 0.9427 - recall: 0.9808 - val_accuracy: 0.8996 - val_loss: 0.2445 - val_precision: 0.8636 - val_recall: 0.9500 - learning_rate: 5.0000e-05
# Epoch 44/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9665 - loss: 0.1032 - precision: 0.9427 - recall: 0.9914  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9690 - loss: 0.1098 - precision: 0.9519 - recall: 0.9885 - val_accuracy: 0.9038 - val_loss: 0.2461 - val_precision: 0.8702 - val_recall: 0.9500 - learning_rate: 5.0000e-05
# Epoch 45/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9688 - loss: 0.0972 - precision: 0.9499 - recall: 0.9892  val_f1_weighted: 0.8993 (mejor: 0.9076 en época 24)
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.9632 - loss: 0.1057 - precision: 0.9414 - recall: 0.9885 - val_accuracy: 0.8996 - val_loss: 0.2441 - val_precision: 0.8636 - val_recall: 0.9500 - learning_rate: 5.0000e-05
# Epoch 46/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9705 - loss: 0.0950 - precision: 0.9558 - recall: 0.9862  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 98ms/step - accuracy: 0.9680 - loss: 0.1044 - precision: 0.9501 - recall: 0.9885 - val_accuracy: 0.9038 - val_loss: 0.2439 - val_precision: 0.8702 - val_recall: 0.9500 - learning_rate: 2.5000e-05
# Epoch 47/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9633 - loss: 0.1063 - precision: 0.9474 - recall: 0.9802  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.9641 - loss: 0.1097 - precision: 0.9481 - recall: 0.9827 - val_accuracy: 0.9038 - val_loss: 0.2421 - val_precision: 0.8702 - val_recall: 0.9500 - learning_rate: 2.5000e-05
# Epoch 48/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9690 - loss: 0.0989 - precision: 0.9552 - recall: 0.9836  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.9680 - loss: 0.1067 - precision: 0.9501 - recall: 0.9885 - val_accuracy: 0.9038 - val_loss: 0.2439 - val_precision: 0.8702 - val_recall: 0.9500 - learning_rate: 2.5000e-05
# Epoch 49/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9698 - loss: 0.0973 - precision: 0.9548 - recall: 0.9859  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.9632 - loss: 0.1072 - precision: 0.9463 - recall: 0.9827 - val_accuracy: 0.9038 - val_loss: 0.2435 - val_precision: 0.8702 - val_recall: 0.9500 - learning_rate: 2.5000e-05
# Epoch 50/50
# 64/65 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9683 - loss: 0.1022 - precision: 0.9411 - recall: 0.9972  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 24)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.9661 - loss: 0.1044 - precision: 0.9433 - recall: 0.9923 - val_accuracy: 0.9038 - val_loss: 0.2432 - val_precision: 0.8702 - val_recall: 0.9500 - learning_rate: 1.2500e-05
#
# 🏆 Mejor F1 en validación: 0.9076 (época 24)
#    Restaurando mejores pesos...
#    ✅ Pesos restaurados.
#
# =======================================================
# 🏆 MEJOR ÉPOCA (F1): 24
#    Mejor Val F1      : 0.9076
# =======================================================

# %%
# ─── EXP 60: Curvas de entrenamiento ──────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()
metrics_plot = [
    ('accuracy','val_accuracy','Accuracy'),
    ('loss','val_loss','Loss'),
    ('precision','val_precision','Precision'),
    ('recall','val_recall','Recall'),
]
for ax, (tk, vk, lbl) in zip(axes, metrics_plot):
    ep = range(1, len(history.history[tk])+1)
    ax.plot(ep, history.history[tk], 'b-o', ms=4, label='Train')
    ax.plot(ep, history.history[vk], 'r-o', ms=4, label='Val')
    be = int(np.argmin(history.history[vk]) if 'loss' in vk else np.argmax(history.history[vk]))
    ax.axvline(be+1, color='green', ls='--', alpha=0.7, label=f'Mejor ({be+1})')
    ax.set_title(lbl, fontweight='bold')
    ax.set_xlabel('Época'); ax.set_ylabel(lbl)
    ax.legend(); ax.grid(True, alpha=0.3)

fig2, ax2 = plt.subplots(figsize=(8, 4))
ax2.plot(range(1, len(f1_callback.f1_history)+1), f1_callback.f1_history, 'g-o', ms=4)
ax2.axvline(f1_callback.best_epoch, color='red', ls='--',
            label=f'Mejor F1={f1_callback.best_f1:.4f} (época {f1_callback.best_epoch})')
ax2.set_title('Val F1-Score Weighted por Época', fontweight='bold')
ax2.set_xlabel('Época'); ax2.set_ylabel('F1-Score')
ax2.legend(); ax2.grid(True, alpha=0.3)
fig2.tight_layout()
fig2.savefig(f'resultados/f1_curve_{exp_name}.png', dpi=130, bbox_inches='tight')

title = f"EXP {CFG['EXPERIMENT_ID']:02d} — {CFG['EXPERIMENT_NAME']}"
fig.suptitle(f'Curvas — {title}', fontsize=13, fontweight='bold')
fig.tight_layout()
fig.savefig(f'resultados/curvas_{exp_name}.png', dpi=130, bbox_inches='tight')
plt.show()

# %%
# ─── EXP 60: Evaluación Train / Valid / Test ──────────────────────
y_tr, yp_tr, loss_tr = evaluar(train_ds, 'ENTRENAMIENTO')
y_va, yp_va, loss_va = evaluar(val_ds,   'VALIDACIÓN')
y_te, yp_te, loss_te = evaluar(test_ds,  'PRUEBA (Test) ★')

(acc_tr,acc_va,acc_te), (prec_tr,prec_va,prec_te), \
(rec_tr,rec_va,rec_te), (f1_tr,f1_va,f1_te) = metrics_row(
    y_tr, yp_tr, y_va, yp_va, y_te, yp_te)

print('\n' + '='*65)
print(f'  📊 EXP 60 — MÉTRICAS GLOBALES')
print('='*65)
print(f"{'Métrica':<28} {'Train':>10} {'Validación':>12} {'Test':>10}")
print('-'*65)
rows_exp = [
    ('Exactitud (Accuracy)',  acc_tr,  acc_va,  acc_te),
    ('Pérdida (BCE Loss)',    loss_tr, loss_va, loss_te),
    ('Precisión (Weighted)', prec_tr, prec_va, prec_te),
    ('Recall (Weighted)',    rec_tr,  rec_va,  rec_te),
    ('F1-Score (Weighted)',  f1_tr,   f1_va,   f1_te),
]
for label, tr, va, te in rows_exp:
    print(f"  {label:<26} {tr:>10.4f} {va:>12.4f} {te:>10.4f}")
print('='*65)
print(f"  {'★ Mejor época (F1)':<26} {f1_callback.best_epoch:>10}")
print(f"  {'★ Mejor val_f1':<26} {f1_callback.best_f1:>10.4f}")
print('='*65)

# Guardar resumen en tabla global
RESULTS_TABLE.append({
    'EXP': f'EXP60',
    'NOMBRE': 'Best_E_BS16_DU64_D3',
    'LR': 5e-05, 'BS': 16, 'DU': 64,
    'OPT': 'Adam', 'DROP': 0.3, 'L2': 1e-05, 'BN': True,
    'val_f1': round(f1_callback.best_f1, 4),
    'test_f1': round(f1_te, 4),
    'test_acc': round(acc_te, 4),
    'test_prec': round(prec_te, 4),
    'test_rec': round(rec_te, 4),
    'best_epoch': f1_callback.best_epoch,
})
# Out:
# ==========================================================
#   ENTRENAMIENTO
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9873    0.9141    0.9493       512
#        Sanos     0.9211    0.9885    0.9536       520
#
#     accuracy                         0.9516      1032
#    macro avg     0.9542    0.9513    0.9515      1032
# weighted avg     0.9540    0.9516    0.9515      1032
#
# ==========================================================
#   VALIDACIÓN
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9619    0.8487    0.9018       119
#        Sanos     0.8657    0.9667    0.9134       120
#
#     accuracy                         0.9079       239
#    macro avg     0.9138    0.9077    0.9076       239
# weighted avg     0.9136    0.9079    0.9076       239
#
# ==========================================================
#   PRUEBA (Test) ★
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9931    0.8773    0.9316       163
#        Sanos     0.8837    0.9935    0.9354       153
#
#     accuracy                         0.9335       316
#    macro avg     0.9384    0.9354    0.9335       316
# weighted avg     0.9401    0.9335    0.9334       316
#
#
# =================================================================
#   📊 EXP 60 — MÉTRICAS GLOBALES
# =================================================================
# Métrica                           Train   Validación       Test
# -----------------------------------------------------------------
#   Exactitud (Accuracy)           0.9516       0.9079     0.9335
#   Pérdida (BCE Loss)             0.1352       0.2585     0.1912
#   Precisión (Weighted)           0.9540       0.9136     0.9401
#   Recall (Weighted)              0.9516       0.9079     0.9335
#   F1-Score (Weighted)            0.9515       0.9076     0.9334
# =================================================================
#   ★ Mejor época (F1)                 24
#   ★ Mejor val_f1                 0.9076
# =================================================================

# %%
# ─── EXP 60: Matrices de confusión ────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
plot_cm(y_tr, yp_tr, 'Train',   axes[0], 'Blues')
plot_cm(y_va, yp_va, 'Valid',   axes[1], 'Greens')
plot_cm(y_te, yp_te, 'Test ★', axes[2], 'Oranges')
plt.suptitle(f"Matrices de Confusión — EXP 60",
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'resultados/cm_{exp_name}.png', dpi=130, bbox_inches='tight')
plt.show()

# %%
# ─── EXP 60: Grad-CAM ─────────────────────────────────────────────
LAST_CONV = 'conv5_block32_2_conv'
N = CFG['GRADCAM_SAMPLES']
samples = {0: [], 1: []}
for imgs_raw, lbls in test_ds_raw:
    imgs_prep_batch = preprocess_fn(tf.cast(imgs_raw, tf.float32))
    for img_raw, img_prep, lbl in zip(imgs_raw.numpy(), imgs_prep_batch.numpy(), lbls.numpy()):
        c = int(lbl)
        if len(samples[c]) < N:
            samples[c].append((img_raw.astype(np.uint8), img_prep))
    if all(len(v) >= N for v in samples.values()):
        break

ALPHA = CFG['GRADCAM_ALPHA']
for clase_idx, clase_name in enumerate(class_names):
    imgs_list = samples[clase_idx]
    n_cols = min(N, len(imgs_list))
    fig, axes = plt.subplots(2, n_cols, figsize=(3 * n_cols, 7))
    fig.suptitle(f'Grad-CAM — Clase: {clase_name}  |  EXP 60',
                 fontsize=13, fontweight='bold')
    for col, (img_orig, img_prep) in enumerate(imgs_list[:n_cols]):
        inp = img_prep[np.newaxis, ...].astype(np.float32)
        heatmap = get_gradcam_heatmap(inp, model, LAST_CONV)
        overlay = overlay_gradcam(img_orig, heatmap, alpha=ALPHA)
        prob    = model.predict(inp, verbose=0)[0][0]
        pred_name = class_names[int(prob > 0.5)]
        axes[0, col].imshow(img_orig)
        axes[0, col].set_title(f'Original\nProb={prob:.2f}', fontsize=8)
        axes[0, col].axis('off')
        axes[1, col].imshow(overlay)
        axes[1, col].set_title(f'Grad-CAM\nPred: {pred_name}', fontsize=8)
        axes[1, col].axis('off')
    plt.tight_layout()
    fname = f'resultados/gradcam_{exp_name}_{clase_name}.png'
    plt.savefig(fname, dpi=130, bbox_inches='tight')
    plt.show()
    print(f'  💾 {fname}')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# ─── Resumen final EXP 60 ──────────────────────────────────────────
if RESULTS_TABLE:
    r = RESULTS_TABLE[0]
    print('\n' + '★'*60)
    print(f'  🏆 RESULTADO — EXP 60: Best_E_BS16_DU64_D3')
    print('★'*60)
    for k, v in r.items():
        print(f'  {k:<16}: {v}')
    print('★'*60)
    df_exp = pd.DataFrame(RESULTS_TABLE)
    df_exp.to_csv(f'resultados/resumen_EXP60_Best_E_BS16_DU64_D3.csv', index=False)
    print('\n💾 CSV guardado: resultados/resumen_EXP60_Best_E_BS16_DU64_D3.csv')
else:
    print('⚠️ RESULTS_TABLE vacía — ejecuta las celdas anteriores primero')
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#   🏆 RESULTADO — EXP 60: Best_E_BS16_DU64_D3
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#   EXP             : EXP60
#   NOMBRE          : Best_E_BS16_DU64_D3
#   LR              : 5e-05
#   BS              : 16
#   DU              : 64
#   OPT             : Adam
#   DROP            : 0.3
#   L2              : 1e-05
#   BN              : True
#   val_f1          : 0.9076
#   test_f1         : 0.9334
#   test_acc        : 0.9335
#   test_prec       : 0.9401
#   test_rec        : 0.9335
#   best_epoch      : 24
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#
# 💾 CSV guardado: resultados/resumen_EXP60_Best_E_BS16_DU64_D3.csv

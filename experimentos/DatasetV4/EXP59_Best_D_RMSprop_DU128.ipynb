# %% [markdown]
# # 🥭 EXP 59 — Best_D_RMSprop_DU128
# ## DenseNet169 | Transfer Learning (base congelada)
# > ⚡ **Google Colab** — Activar GPU: `Entorno de ejecución → Cambiar tipo → T4 GPU`
#
# | Hiperparámetro | Valor |
# |---|---|
# | Learning Rate | `0.0001` |
# | Batch Size | `32` |
# | Épocas máx. | `50` |
# | Optimizador | `RMSprop` |
# | Dropout | `0.4` |
# | Dense Units | `128` |
# | L2 Regularización | `1e-05` |
# | EarlyStopping patience | `10` |
# | BatchNorm cabeza | `True` |
# | Criterio mejor modelo | **F1-Score weighted** |

# %%
# !pip install -q kagglehub seaborn scikit-learn
print('✅ Paquetes instalados')
# Out:
# ✅ Paquetes instalados

# %%
import os, json, warnings, math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import pandas as pd
import tensorflow as tf
import kagglehub
from tensorflow import keras
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, Callback
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import (classification_report, confusion_matrix,
                              f1_score, precision_score, recall_score, accuracy_score)
from sklearn.utils import class_weight
warnings.filterwarnings('ignore')
print(f'TensorFlow: {tf.__version__}')
print(f'GPU: {tf.config.list_physical_devices("GPU")}')
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ─── Descarga del dataset (una sola vez) ──────────────────────────────────
kaggle_credentials = {
    'username': 'datasetdense169',
    'key': '58501601b86ccbf504958f6bff2df66b'
}
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)
with open(os.path.expanduser('~/.kaggle/kaggle.json'), 'w') as f:
    json.dump(kaggle_credentials, f)
os.chmod(os.path.expanduser('~/.kaggle/kaggle.json'), 0o600)

download_path = kagglehub.dataset_download('datasetdense169/datasetmangokent')
dataset_path  = os.path.join(download_path, 'DatasetV4_MejoraSelectiva')
train_dir = os.path.join(dataset_path, 'train')
val_dir   = os.path.join(dataset_path, 'valid')
test_dir  = os.path.join(dataset_path, 'test')

for split, path in [('train', train_dir), ('valid', val_dir), ('test', test_dir)]:
    if os.path.exists(path):
        clases = sorted([d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))])
        total  = sum(len([f for f in os.listdir(os.path.join(path, c))
                          if f.lower().endswith(('.jpg','.jpeg','.png'))]) for c in clases)
        print(f'  ✓ {split:6s}: {total:>5} imgs | clases: {clases}')
    else:
        print(f'  ✗ {split} NO encontrado')
# Out:
# Using Colab cache for faster access to the 'datasetmangokent' dataset.
#   ✓ train :  1032 imgs | clases: ['Defectuoso', 'Sanos']
#   ✓ valid :   239 imgs | clases: ['Defectuoso', 'Sanos']
#   ✓ test  :   316 imgs | clases: ['Defectuoso', 'Sanos']

# %%
# ─── Resultados de este experimento ─────────────────────────────────
RESULTS_TABLE = []  # tabla local para este experimento
print('✅ EXP 59 — Best_D_RMSprop_DU128 — Notebook individual')
print('   Criterio de selección: F1-Score weighted en validación')
# Out:
# ✅ EXP 59 — Best_D_RMSprop_DU128 — Notebook individual
#    Criterio de selección: F1-Score weighted en validación

# %%
# ─── Callback: Mejor modelo por F1-Score ────────────────────────────────
class BestF1Checkpoint(Callback):
    def __init__(self, val_ds, ckpt_path, verbose=1):
        super().__init__()
        self.val_ds    = val_ds
        self.ckpt_path = ckpt_path
        self.best_f1   = -1.0
        self.best_epoch = 0
        self.verbose   = verbose
        self.f1_history = []

    def on_epoch_end(self, epoch, logs=None):
        y_true, y_pred = [], []
        for x_batch, y_batch in self.val_ds:
            preds = self.model.predict(x_batch, verbose=0)
            y_true.extend(y_batch.numpy().flatten().astype(int))
            y_pred.extend((preds.flatten() > 0.5).astype(int))
        current_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
        self.f1_history.append(current_f1)
        if self.verbose:
            print(f'  val_f1_weighted: {current_f1:.4f}', end='')
        if current_f1 > self.best_f1:
            self.best_f1    = current_f1
            self.best_epoch = epoch + 1
            self.model.save_weights(self.ckpt_path)
            if self.verbose:
                print(f' ✅ Nuevo mejor F1 — pesos guardados')
        else:
            if self.verbose:
                print(f' (mejor: {self.best_f1:.4f} en época {self.best_epoch})')

    def on_train_end(self, logs=None):
        print(f'\n🏆 Mejor F1 en validación: {self.best_f1:.4f} (época {self.best_epoch})')
        print(f'   Restaurando mejores pesos...')
        self.model.load_weights(self.ckpt_path)
        print('   ✅ Pesos restaurados.')

print('✅ Callback BestF1Checkpoint definido')
# Out:
# ✅ Callback BestF1Checkpoint definido

# %%
# ─── Función de construcción del modelo (Transfer Learning puro) ──────────
def get_optimizer():
    opt = CFG['OPTIMIZER']
    lr  = CFG['LR']
    if   opt == 'Adam'        : return keras.optimizers.Adam(learning_rate=lr)
    elif opt == 'Adamax'      : return keras.optimizers.Adamax(learning_rate=lr)
    elif opt == 'SGD'         : return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    elif opt == 'SGD_Nesterov': return keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True)
    elif opt == 'RMSprop'     : return keras.optimizers.RMSprop(learning_rate=lr)
    else: raise ValueError(f'Optimizador desconocido: {opt}')

def build_model():
    base = DenseNet169(weights='imagenet', include_top=False,
                       input_shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3))
    base.trainable = False  # ← Transfer Learning puro: base CONGELADA

    inputs = keras.Input(shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3))
    x = base(inputs, training=False)
    x = GlobalAveragePooling2D(name='gap')(x)
    if CFG['BN_HEAD']:
        x = BatchNormalization(name='bn_head')(x)
    x = Dropout(CFG['DROPOUT'], name='drop1')(x)
    x = Dense(CFG['DENSE_UNITS'], activation='relu',
              kernel_regularizer=keras.regularizers.l2(CFG['L2']),
              name='dense_head')(x)
    x = Dropout(CFG['DROPOUT'] * 0.6, name='drop2')(x)
    outputs = Dense(1, activation='sigmoid', name='output')(x)

    model = Model(inputs, outputs, name=f"DenseNet169_TL_EXP{CFG['EXPERIMENT_ID']:02d}")
    model.compile(
        optimizer=get_optimizer(),
        loss='binary_crossentropy',
        metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
    )
    return model

print('✅ Función build_model definida (Transfer Learning puro)')
# Out:
# ✅ Función build_model definida (Transfer Learning puro)

# %%
# ─── Funciones de evaluación ─────────────────────────────────────────────
def evaluar(ds_prep, nombre):
    y_true, y_pred, y_prob = [], [], []
    for imgs, lbls in ds_prep:
        preds = model.predict(imgs, verbose=0)
        y_true.extend(lbls.numpy().flatten())
        y_prob.extend(preds.flatten())
        y_pred.extend((preds > 0.5).astype(int).flatten())
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)
    print(f"{'='*58}")
    print(f'  {nombre}')
    print(f"{'='*58}")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    eps = 1e-7
    loss = -np.mean(y_true * np.log(y_prob + eps) + (1 - y_true) * np.log(1 - y_prob + eps))
    return y_true, y_pred, loss

def metrics_row(y_t, yp_t, y_v, yp_v, y_te_, yp_te_):
    acc_tr  = accuracy_score(y_t,   yp_t)
    acc_va  = accuracy_score(y_v,   yp_v)
    acc_te  = accuracy_score(y_te_, yp_te_)
    prec_tr = precision_score(y_t,   yp_t,   average='weighted', zero_division=0)
    prec_va = precision_score(y_v,   yp_v,   average='weighted', zero_division=0)
    prec_te = precision_score(y_te_, yp_te_, average='weighted', zero_division=0)
    rec_tr  = recall_score(y_t,   yp_t,   average='weighted', zero_division=0)
    rec_va  = recall_score(y_v,   yp_v,   average='weighted', zero_division=0)
    rec_te  = recall_score(y_te_, yp_te_, average='weighted', zero_division=0)
    f1_tr   = f1_score(y_t,   yp_t,   average='weighted', zero_division=0)
    f1_va   = f1_score(y_v,   yp_v,   average='weighted', zero_division=0)
    f1_te   = f1_score(y_te_, yp_te_, average='weighted', zero_division=0)
    return (acc_tr,acc_va,acc_te), (prec_tr,prec_va,prec_te), \
           (rec_tr,rec_va,rec_te), (f1_tr,f1_va,f1_te)

def plot_cm(y_true, y_pred, title, ax, cmap='Blues'):
    cm_ = confusion_matrix(y_true, y_pred)
    norm = cm_.astype(float) / cm_.sum(axis=1)[:,None]
    ann  = [[f'{v}\n({p:.1%})' for v,p in zip(r,rn)] for r,rn in zip(cm_,norm)]
    sns.heatmap(cm_, annot=ann, fmt='', cmap=cmap, ax=ax,
                xticklabels=class_names, yticklabels=class_names,
                annot_kws={'size':11,'weight':'bold'})
    acc = accuracy_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred, average='weighted')
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel(f'Predicho\nAcc={acc:.4f}  F1={f1:.4f}')
    ax.set_ylabel('Real')

print('✅ Funciones de evaluación definidas')
# Out:
# ✅ Funciones de evaluación definidas

# %%
# ─── Funciones Grad-CAM ──────────────────────────────────────────────────
def get_gradcam_heatmap(img_array, model, last_conv_layer_name='conv5_block32_2_conv'):
    base_model = model.get_layer('densenet169')
    last_conv = base_model.get_layer(last_conv_layer_name)
    base_grad_model = tf.keras.models.Model(
        inputs=base_model.inputs,
        outputs=[last_conv.output, base_model.output]
    )
    img_var = tf.Variable(tf.cast(img_array, tf.float32))
    with tf.GradientTape() as tape:
        conv_outputs, base_out = base_grad_model(img_var, training=False)
        x = base_out
        for lname in ['gap', 'bn_head', 'drop1', 'dense_head', 'drop2', 'output']:
            try:
                lyr = model.get_layer(lname)
                x = lyr(x, training=False)
            except Exception:
                pass
        loss = x[:, 0]
    grads        = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap      = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap      = tf.squeeze(heatmap)
    heatmap      = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

def overlay_gradcam(original_img, heatmap, alpha=0.4):
    heatmap_resized = np.array(
        tf.image.resize(heatmap[..., np.newaxis],
                        (original_img.shape[0], original_img.shape[1]))
    ).squeeze()
    heatmap_uint8 = np.uint8(255 * heatmap_resized)
    jet_colors    = cm.get_cmap('jet')(np.arange(256))[:, :3]
    jet_heatmap   = jet_colors[heatmap_uint8]
    jet_heatmap   = np.uint8(jet_heatmap * 255)
    superimposed  = jet_heatmap * alpha + original_img * (1 - alpha)
    return np.uint8(superimposed)

print('✅ Funciones Grad-CAM definidas')
# Out:
# ✅ Funciones Grad-CAM definidas

# %%
# ─── EXP 59: Best_D_RMSprop_DU128 ─────────────────────────────────────────────
CFG = {
    'EXPERIMENT_ID'  : 59,
    'EXPERIMENT_NAME': 'Best_D_RMSprop_DU128',
    'DESCRIPCION'    : 'Candidato D — RMSprop drop40',

    # ── Rutas ──────────────────────────────────────────────────────
    'DATASET_VERSION': 'DatasetV3_Roboflow',

    # ── Imágenes ───────────────────────────────────────────────────
    'IMG_SIZE'  : 224,
    'BATCH_SIZE': 32,
    'SEED'      : 42,

    # ── Entrenamiento ──────────────────────────────────────────────
    'EPOCHS'    : 50,
    'LR'        : 0.0001,
    'OPTIMIZER' : 'RMSprop',
    'PATIENCE'  : 10,
    'RLR_FACTOR': 0.5,

    # ── Arquitectura del head ──────────────────────────────────────
    'DENSE_UNITS': 128,
    'DROPOUT'    : 0.4,
    'L2'         : 1e-05,
    'BN_HEAD'    : True,

    # ── Grad-CAM ──────────────────────────────────────────────────
    'GRADCAM_SAMPLES': 8,
    'GRADCAM_ALPHA'  : 0.4,
}

tf.random.set_seed(CFG['SEED'])
np.random.seed(CFG['SEED'])
os.makedirs('checkpoints', exist_ok=True)
os.makedirs('resultados',  exist_ok=True)

print('\n📋 CONFIGURACIÓN — EXP 59: Best_D_RMSprop_DU128')
for k, v in CFG.items():
    print(f'  {k:<20}: {v}')
# Out:
# 📋 CONFIGURACIÓN — EXP 59: Best_D_RMSprop_DU128
#   EXPERIMENT_ID       : 59
#   EXPERIMENT_NAME     : Best_D_RMSprop_DU128
#   DESCRIPCION         : Candidato D — RMSprop drop40
#   DATASET_VERSION     : DatasetV3_Roboflow
#   IMG_SIZE            : 224
#   BATCH_SIZE          : 32
#   SEED                : 42
#   EPOCHS              : 50
#   LR                  : 0.0001
#   OPTIMIZER           : RMSprop
#   PATIENCE            : 10
#   RLR_FACTOR          : 0.5
#   DENSE_UNITS         : 128
#   DROPOUT             : 0.4
#   L2                  : 1e-05
#   BN_HEAD             : True
#   GRADCAM_SAMPLES     : 8
#   GRADCAM_ALPHA       : 0.4

# %%
# ─── EXP 59: Carga y preprocesamiento ────────────────────────────
IMG  = CFG['IMG_SIZE']
BS   = CFG['BATCH_SIZE']
SEED = CFG['SEED']

train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    train_dir, labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=True, seed=SEED)
val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    val_dir,   labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=False)
test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    test_dir,  labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=False)

class_names = train_ds_raw.class_names
preprocess_fn = tf.keras.applications.densenet.preprocess_input

def prepare(ds):
    ds = ds.map(lambda x, y: (preprocess_fn(x), y),
                num_parallel_calls=tf.data.AUTOTUNE)
    return ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds = prepare(train_ds_raw)
val_ds   = prepare(val_ds_raw)
test_ds  = prepare(test_ds_raw)

y_all = np.concatenate([y.numpy().flatten() for _, y in train_ds_raw])
cw    = class_weight.compute_class_weight('balanced', classes=np.unique(y_all), y=y_all)
class_weights_dict = dict(enumerate(cw))
print(f'Clases: {class_names}')
print(f'Pesos: { {class_names[k]: round(v,3) for k,v in class_weights_dict.items()} }')
# Out:
# Found 1032 files belonging to 2 classes.
# Found 239 files belonging to 2 classes.
# Found 316 files belonging to 2 classes.
# Clases: ['Defectuoso', 'Sanos']
# Pesos: {'Defectuoso': np.float64(1.008), 'Sanos': np.float64(0.992)}

# %%
# ─── EXP 59: Construcción del modelo ─────────────────────────────
model = build_model()
trainable = sum(tf.size(w).numpy() for w in model.trainable_weights)
total     = sum(tf.size(w).numpy() for w in model.weights)
print(f'Parámetros entrenables: {trainable:,} / {total:,} ({100*trainable/total:.2f}%)')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Parámetros entrenables: 216,577 / 12,862,785 (1.68%)

# %%
# ─── EXP 59: Entrenamiento ────────────────────────────────────────
exp_name  = f"EXP{CFG['EXPERIMENT_ID']:02d}_{CFG['EXPERIMENT_NAME']}"
ckpt_path = f"checkpoints/best_{exp_name}.weights.h5"

f1_callback = BestF1Checkpoint(val_ds, ckpt_path, verbose=1)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=CFG['PATIENCE'],
                  restore_best_weights=False, verbose=1),
    f1_callback,
    ReduceLROnPlateau(monitor='val_loss', factor=CFG['RLR_FACTOR'],
                      patience=4, min_lr=1e-8, verbose=1),
    CSVLogger(f"resultados/log_{exp_name}.csv", append=False),
]

print(f'\n=== EXPERIMENTO {CFG["EXPERIMENT_ID"]:02d}: {CFG["EXPERIMENT_NAME"]} ===')
print(f'Desc: {CFG["DESCRIPCION"]}\n')

history = model.fit(
    train_ds, epochs=CFG['EPOCHS'],
    validation_data=val_ds,
    callbacks=callbacks,
    class_weight=class_weights_dict,
    verbose=1
)

print(f'\n{"="*55}')
print(f'🏆 MEJOR ÉPOCA (F1): {f1_callback.best_epoch}')
print(f'   Mejor Val F1      : {f1_callback.best_f1:.4f}')
print(f'{"="*55}')
# Out:
# === EXPERIMENTO 59: Best_D_RMSprop_DU128 ===
# Desc: Candidato D — RMSprop drop40
#
# Epoch 1/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.7194 - loss: 0.5633 - precision: 0.6897 - recall: 0.7786  val_f1_weighted: 0.8291 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 154s 3s/step - accuracy: 0.7878 - loss: 0.4712 - precision: 0.7564 - recall: 0.8538 - val_accuracy: 0.8326 - val_loss: 0.4698 - val_precision: 0.7597 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 2/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8591 - loss: 0.4001 - precision: 0.8118 - recall: 0.9280  val_f1_weighted: 0.8554 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 198ms/step - accuracy: 0.8488 - loss: 0.3776 - precision: 0.8033 - recall: 0.9269 - val_accuracy: 0.8577 - val_loss: 0.4007 - val_precision: 0.7867 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 3/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8699 - loss: 0.3245 - precision: 0.8238 - recall: 0.9343  val_f1_weighted: 0.8595 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.8750 - loss: 0.3182 - precision: 0.8365 - recall: 0.9346 - val_accuracy: 0.8619 - val_loss: 0.3645 - val_precision: 0.7881 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 4/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8859 - loss: 0.2936 - precision: 0.8365 - recall: 0.9538  val_f1_weighted: 0.8683 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.8857 - loss: 0.2958 - precision: 0.8384 - recall: 0.9577 - val_accuracy: 0.8703 - val_loss: 0.3345 - val_precision: 0.7987 - val_recall: 0.9917 - learning_rate: 1.0000e-04
# Epoch 5/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8992 - loss: 0.2903 - precision: 0.8520 - recall: 0.9609  val_f1_weighted: 0.8642 (mejor: 0.8683 en época 4)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.8992 - loss: 0.2736 - precision: 0.8549 - recall: 0.9635 - val_accuracy: 0.8661 - val_loss: 0.3150 - val_precision: 0.7973 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 6/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8880 - loss: 0.2697 - precision: 0.8445 - recall: 0.9450  val_f1_weighted: 0.8729 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.8924 - loss: 0.2572 - precision: 0.8544 - recall: 0.9481 - val_accuracy: 0.8745 - val_loss: 0.3029 - val_precision: 0.8082 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 7/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9040 - loss: 0.2491 - precision: 0.8535 - recall: 0.9705  val_f1_weighted: 0.8902 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.9002 - loss: 0.2469 - precision: 0.8601 - recall: 0.9577 - val_accuracy: 0.8912 - val_loss: 0.2904 - val_precision: 0.8310 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 8/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9001 - loss: 0.2200 - precision: 0.8599 - recall: 0.9515  val_f1_weighted: 0.8902 (mejor: 0.8902 en época 7)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.9021 - loss: 0.2236 - precision: 0.8669 - recall: 0.9519 - val_accuracy: 0.8912 - val_loss: 0.2802 - val_precision: 0.8310 - val_recall: 0.9833 - learning_rate: 1.0000e-04
# Epoch 9/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9192 - loss: 0.2004 - precision: 0.8725 - recall: 0.9781  val_f1_weighted: 0.8861 (mejor: 0.8902 en época 7)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9196 - loss: 0.2057 - precision: 0.8774 - recall: 0.9769 - val_accuracy: 0.8870 - val_loss: 0.2748 - val_precision: 0.8298 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 10/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9175 - loss: 0.1985 - precision: 0.8785 - recall: 0.9649  val_f1_weighted: 0.8948 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 204ms/step - accuracy: 0.9264 - loss: 0.1939 - precision: 0.8936 - recall: 0.9692 - val_accuracy: 0.8954 - val_loss: 0.2724 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 11/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9078 - loss: 0.2008 - precision: 0.8695 - recall: 0.9552  val_f1_weighted: 0.8950 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - accuracy: 0.9215 - loss: 0.1973 - precision: 0.8885 - recall: 0.9654 - val_accuracy: 0.8954 - val_loss: 0.2692 - val_precision: 0.8519 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 12/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9330 - loss: 0.1902 - precision: 0.8949 - recall: 0.9776  val_f1_weighted: 0.8991 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9331 - loss: 0.1829 - precision: 0.9020 - recall: 0.9731 - val_accuracy: 0.8996 - val_loss: 0.2622 - val_precision: 0.8529 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 13/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9191 - loss: 0.1779 - precision: 0.8894 - recall: 0.9532  val_f1_weighted: 0.8991 (mejor: 0.8991 en época 12)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.9293 - loss: 0.1746 - precision: 0.9056 - recall: 0.9596 - val_accuracy: 0.8996 - val_loss: 0.2578 - val_precision: 0.8529 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 14/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9386 - loss: 0.1704 - precision: 0.9072 - recall: 0.9745  val_f1_weighted: 0.8992 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9360 - loss: 0.1758 - precision: 0.9083 - recall: 0.9712 - val_accuracy: 0.8996 - val_loss: 0.2549 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 15/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9304 - loss: 0.1774 - precision: 0.8971 - recall: 0.9689  val_f1_weighted: 0.9035 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.9312 - loss: 0.1764 - precision: 0.9016 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2555 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 16/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9403 - loss: 0.1681 - precision: 0.9125 - recall: 0.9717  val_f1_weighted: 0.9076 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step - accuracy: 0.9360 - loss: 0.1693 - precision: 0.9068 - recall: 0.9731 - val_accuracy: 0.9079 - val_loss: 0.2535 - val_precision: 0.8657 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 17/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9371 - loss: 0.1681 - precision: 0.9076 - recall: 0.9706  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 16)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - accuracy: 0.9370 - loss: 0.1634 - precision: 0.9099 - recall: 0.9712 - val_accuracy: 0.9038 - val_loss: 0.2507 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 18/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9428 - loss: 0.1500 - precision: 0.9210 - recall: 0.9661  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 16)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 161ms/step - accuracy: 0.9457 - loss: 0.1490 - precision: 0.9265 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2515 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 19/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9307 - loss: 0.1523 - precision: 0.9081 - recall: 0.9555  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 16)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - accuracy: 0.9331 - loss: 0.1554 - precision: 0.9093 - recall: 0.9635 - val_accuracy: 0.9038 - val_loss: 0.2467 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 20/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9465 - loss: 0.1422 - precision: 0.9237 - recall: 0.9711  val_f1_weighted: 0.9035 (mejor: 0.9076 en época 16)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - accuracy: 0.9486 - loss: 0.1461 - precision: 0.9269 - recall: 0.9750 - val_accuracy: 0.9038 - val_loss: 0.2513 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 21/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9432 - loss: 0.1412 - precision: 0.9172 - recall: 0.9721  val_f1_weighted: 0.9077 ✅ Nuevo mejor F1 — pesos guardados
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 222ms/step - accuracy: 0.9409 - loss: 0.1475 - precision: 0.9135 - recall: 0.9750 - val_accuracy: 0.9079 - val_loss: 0.2538 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 22/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9547 - loss: 0.1364 - precision: 0.9333 - recall: 0.9769  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.9564 - loss: 0.1397 - precision: 0.9358 - recall: 0.9808 - val_accuracy: 0.9079 - val_loss: 0.2536 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 23/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9424 - loss: 0.1387 - precision: 0.9140 - recall: 0.9738  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - accuracy: 0.9467 - loss: 0.1374 - precision: 0.9235 - recall: 0.9750 - val_accuracy: 0.9079 - val_loss: 0.2520 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 24/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9401 - loss: 0.1332 - precision: 0.9067 - recall: 0.9783  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.9486 - loss: 0.1306 - precision: 0.9253 - recall: 0.9769 - val_accuracy: 0.9079 - val_loss: 0.2513 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 25/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9493 - loss: 0.1216 - precision: 0.9277 - recall: 0.9725  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.9516 - loss: 0.1279 - precision: 0.9320 - recall: 0.9750 - val_accuracy: 0.9079 - val_loss: 0.2516 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 26/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9583 - loss: 0.1171 - precision: 0.9311 - recall: 0.9878  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.9564 - loss: 0.1238 - precision: 0.9326 - recall: 0.9846 - val_accuracy: 0.9079 - val_loss: 0.2532 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 27/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9591 - loss: 0.1178 - precision: 0.9331 - recall: 0.9872  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.9554 - loss: 0.1234 - precision: 0.9325 - recall: 0.9827 - val_accuracy: 0.9079 - val_loss: 0.2511 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 28/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9611 - loss: 0.1131 - precision: 0.9448 - recall: 0.9785  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.9603 - loss: 0.1155 - precision: 0.9394 - recall: 0.9846 - val_accuracy: 0.9079 - val_loss: 0.2512 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 29/50
# 32/33 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9679 - loss: 0.1029 - precision: 0.9428 - recall: 0.9952  val_f1_weighted: 0.9077 (mejor: 0.9077 en época 21)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.9593 - loss: 0.1186 - precision: 0.9330 - recall: 0.9904 - val_accuracy: 0.9079 - val_loss: 0.2519 - val_precision: 0.8712 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 29: early stopping
#
# 🏆 Mejor F1 en validación: 0.9077 (época 21)
#    Restaurando mejores pesos...
#    ✅ Pesos restaurados.
#
# =======================================================
# 🏆 MEJOR ÉPOCA (F1): 21
#    Mejor Val F1      : 0.9077
# =======================================================

# %%
# ─── EXP 59: Curvas de entrenamiento ──────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()
metrics_plot = [
    ('accuracy','val_accuracy','Accuracy'),
    ('loss','val_loss','Loss'),
    ('precision','val_precision','Precision'),
    ('recall','val_recall','Recall'),
]
for ax, (tk, vk, lbl) in zip(axes, metrics_plot):
    ep = range(1, len(history.history[tk])+1)
    ax.plot(ep, history.history[tk], 'b-o', ms=4, label='Train')
    ax.plot(ep, history.history[vk], 'r-o', ms=4, label='Val')
    be = int(np.argmin(history.history[vk]) if 'loss' in vk else np.argmax(history.history[vk]))
    ax.axvline(be+1, color='green', ls='--', alpha=0.7, label=f'Mejor ({be+1})')
    ax.set_title(lbl, fontweight='bold')
    ax.set_xlabel('Época'); ax.set_ylabel(lbl)
    ax.legend(); ax.grid(True, alpha=0.3)

fig2, ax2 = plt.subplots(figsize=(8, 4))
ax2.plot(range(1, len(f1_callback.f1_history)+1), f1_callback.f1_history, 'g-o', ms=4)
ax2.axvline(f1_callback.best_epoch, color='red', ls='--',
            label=f'Mejor F1={f1_callback.best_f1:.4f} (época {f1_callback.best_epoch})')
ax2.set_title('Val F1-Score Weighted por Época', fontweight='bold')
ax2.set_xlabel('Época'); ax2.set_ylabel('F1-Score')
ax2.legend(); ax2.grid(True, alpha=0.3)
fig2.tight_layout()
fig2.savefig(f'resultados/f1_curve_{exp_name}.png', dpi=130, bbox_inches='tight')

title = f"EXP {CFG['EXPERIMENT_ID']:02d} — {CFG['EXPERIMENT_NAME']}"
fig.suptitle(f'Curvas — {title}', fontsize=13, fontweight='bold')
fig.tight_layout()
fig.savefig(f'resultados/curvas_{exp_name}.png', dpi=130, bbox_inches='tight')
plt.show()

# %%
# ─── EXP 59: Evaluación Train / Valid / Test ──────────────────────
y_tr, yp_tr, loss_tr = evaluar(train_ds, 'ENTRENAMIENTO')
y_va, yp_va, loss_va = evaluar(val_ds,   'VALIDACIÓN')
y_te, yp_te, loss_te = evaluar(test_ds,  'PRUEBA (Test) ★')

(acc_tr,acc_va,acc_te), (prec_tr,prec_va,prec_te), \
(rec_tr,rec_va,rec_te), (f1_tr,f1_va,f1_te) = metrics_row(
    y_tr, yp_tr, y_va, yp_va, y_te, yp_te)

print('\n' + '='*65)
print(f'  📊 EXP 59 — MÉTRICAS GLOBALES')
print('='*65)
print(f"{'Métrica':<28} {'Train':>10} {'Validación':>12} {'Test':>10}")
print('-'*65)
rows_exp = [
    ('Exactitud (Accuracy)',  acc_tr,  acc_va,  acc_te),
    ('Pérdida (BCE Loss)',    loss_tr, loss_va, loss_te),
    ('Precisión (Weighted)', prec_tr, prec_va, prec_te),
    ('Recall (Weighted)',    rec_tr,  rec_va,  rec_te),
    ('F1-Score (Weighted)',  f1_tr,   f1_va,   f1_te),
]
for label, tr, va, te in rows_exp:
    print(f"  {label:<26} {tr:>10.4f} {va:>12.4f} {te:>10.4f}")
print('='*65)
print(f"  {'★ Mejor época (F1)':<26} {f1_callback.best_epoch:>10}")
print(f"  {'★ Mejor val_f1':<26} {f1_callback.best_f1:>10.4f}")
print('='*65)

# Guardar resumen en tabla global
RESULTS_TABLE.append({
    'EXP': f'EXP59',
    'NOMBRE': 'Best_D_RMSprop_DU128',
    'LR': 0.0001, 'BS': 32, 'DU': 128,
    'OPT': 'RMSprop', 'DROP': 0.4, 'L2': 1e-05, 'BN': True,
    'val_f1': round(f1_callback.best_f1, 4),
    'test_f1': round(f1_te, 4),
    'test_acc': round(acc_te, 4),
    'test_prec': round(prec_te, 4),
    'test_rec': round(rec_te, 4),
    'best_epoch': f1_callback.best_epoch,
})
# Out:
# ==========================================================
#   ENTRENAMIENTO
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9878    0.9492    0.9681       512
#        Sanos     0.9519    0.9885    0.9698       520
#
#     accuracy                         0.9690      1032
#    macro avg     0.9698    0.9688    0.9690      1032
# weighted avg     0.9697    0.9690    0.9690      1032
#
# ==========================================================
#   VALIDACIÓN
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9533    0.8571    0.9027       119
#        Sanos     0.8712    0.9583    0.9127       120
#
#     accuracy                         0.9079       239
#    macro avg     0.9122    0.9077    0.9077       239
# weighted avg     0.9121    0.9079    0.9077       239
#
# ==========================================================
#   PRUEBA (Test) ★
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9735    0.9018    0.9363       163
#        Sanos     0.9030    0.9739    0.9371       153
#
#     accuracy                         0.9367       316
#    macro avg     0.9383    0.9378    0.9367       316
# weighted avg     0.9394    0.9367    0.9367       316
#
#
# =================================================================
#   📊 EXP 59 — MÉTRICAS GLOBALES
# =================================================================
# Métrica                           Train   Validación       Test
# -----------------------------------------------------------------
#   Exactitud (Accuracy)           0.9690       0.9079     0.9367
#   Pérdida (BCE Loss)             0.0968       0.2514     0.1815
#   Precisión (Weighted)           0.9697       0.9121     0.9394
#   Recall (Weighted)              0.9690       0.9079     0.9367
#   F1-Score (Weighted)            0.9690       0.9077     0.9367
# =================================================================
#   ★ Mejor época (F1)                 21
#   ★ Mejor val_f1                 0.9077
# =================================================================

# %%
# ─── EXP 59: Matrices de confusión ────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
plot_cm(y_tr, yp_tr, 'Train',   axes[0], 'Blues')
plot_cm(y_va, yp_va, 'Valid',   axes[1], 'Greens')
plot_cm(y_te, yp_te, 'Test ★', axes[2], 'Oranges')
plt.suptitle(f"Matrices de Confusión — EXP 59",
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'resultados/cm_{exp_name}.png', dpi=130, bbox_inches='tight')
plt.show()

# %%
# ─── EXP 59: Grad-CAM ─────────────────────────────────────────────
LAST_CONV = 'conv5_block32_2_conv'
N = CFG['GRADCAM_SAMPLES']
samples = {0: [], 1: []}
for imgs_raw, lbls in test_ds_raw:
    imgs_prep_batch = preprocess_fn(tf.cast(imgs_raw, tf.float32))
    for img_raw, img_prep, lbl in zip(imgs_raw.numpy(), imgs_prep_batch.numpy(), lbls.numpy()):
        c = int(lbl)
        if len(samples[c]) < N:
            samples[c].append((img_raw.astype(np.uint8), img_prep))
    if all(len(v) >= N for v in samples.values()):
        break

ALPHA = CFG['GRADCAM_ALPHA']
for clase_idx, clase_name in enumerate(class_names):
    imgs_list = samples[clase_idx]
    n_cols = min(N, len(imgs_list))
    fig, axes = plt.subplots(2, n_cols, figsize=(3 * n_cols, 7))
    fig.suptitle(f'Grad-CAM — Clase: {clase_name}  |  EXP 59',
                 fontsize=13, fontweight='bold')
    for col, (img_orig, img_prep) in enumerate(imgs_list[:n_cols]):
        inp = img_prep[np.newaxis, ...].astype(np.float32)
        heatmap = get_gradcam_heatmap(inp, model, LAST_CONV)
        overlay = overlay_gradcam(img_orig, heatmap, alpha=ALPHA)
        prob    = model.predict(inp, verbose=0)[0][0]
        pred_name = class_names[int(prob > 0.5)]
        axes[0, col].imshow(img_orig)
        axes[0, col].set_title(f'Original\nProb={prob:.2f}', fontsize=8)
        axes[0, col].axis('off')
        axes[1, col].imshow(overlay)
        axes[1, col].set_title(f'Grad-CAM\nPred: {pred_name}', fontsize=8)
        axes[1, col].axis('off')
    plt.tight_layout()
    fname = f'resultados/gradcam_{exp_name}_{clase_name}.png'
    plt.savefig(fname, dpi=130, bbox_inches='tight')
    plt.show()
    print(f'  💾 {fname}')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# ─── Resumen final EXP 59 ──────────────────────────────────────────
if RESULTS_TABLE:
    r = RESULTS_TABLE[0]
    print('\n' + '★'*60)
    print(f'  🏆 RESULTADO — EXP 59: Best_D_RMSprop_DU128')
    print('★'*60)
    for k, v in r.items():
        print(f'  {k:<16}: {v}')
    print('★'*60)
    df_exp = pd.DataFrame(RESULTS_TABLE)
    df_exp.to_csv(f'resultados/resumen_EXP59_Best_D_RMSprop_DU128.csv', index=False)
    print('\n💾 CSV guardado: resultados/resumen_EXP59_Best_D_RMSprop_DU128.csv')
else:
    print('⚠️ RESULTS_TABLE vacía — ejecuta las celdas anteriores primero')
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#   🏆 RESULTADO — EXP 59: Best_D_RMSprop_DU128
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#   EXP             : EXP59
#   NOMBRE          : Best_D_RMSprop_DU128
#   LR              : 0.0001
#   BS              : 32
#   DU              : 128
#   OPT             : RMSprop
#   DROP            : 0.4
#   L2              : 1e-05
#   BN              : True
#   val_f1          : 0.9077
#   test_f1         : 0.9367
#   test_acc        : 0.9367
#   test_prec       : 0.9394
#   test_rec        : 0.9367
#   best_epoch      : 21
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#
# 💾 CSV guardado: resultados/resumen_EXP59_Best_D_RMSprop_DU128.csv

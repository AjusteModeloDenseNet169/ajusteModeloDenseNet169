# %% [markdown]
# # 🥭 EXP 37 — BS64_DU128_LR1e4
# ## DenseNet169 | Transfer Learning (base congelada)
# > ⚡ **Google Colab** — Activar GPU: `Entorno de ejecución → Cambiar tipo → T4 GPU`
#
# | Hiperparámetro | Valor |
# |---|---|
# | Learning Rate | `0.0001` |
# | Batch Size | `64` |
# | Épocas máx. | `50` |
# | Optimizador | `Adam` |
# | Dropout | `0.5` |
# | Dense Units | `128` |
# | L2 Regularización | `0.0001` |
# | EarlyStopping patience | `10` |
# | BatchNorm cabeza | `True` |
# | Criterio mejor modelo | **F1-Score weighted** |

# %%
# !pip install -q kagglehub seaborn scikit-learn
print('✅ Paquetes instalados')
# Out:
# ✅ Paquetes instalados

# %%
import os, json, warnings, math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import pandas as pd
import tensorflow as tf
import kagglehub
from tensorflow import keras
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, Callback
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import (classification_report, confusion_matrix,
                              f1_score, precision_score, recall_score, accuracy_score)
from sklearn.utils import class_weight
warnings.filterwarnings('ignore')
print(f'TensorFlow: {tf.__version__}')
print(f'GPU: {tf.config.list_physical_devices("GPU")}')
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ─── Descarga del dataset (una sola vez) ──────────────────────────────────
kaggle_credentials = {
    'username': 'datasetdense169',
    'key': '58501601b86ccbf504958f6bff2df66b'
}
os.makedirs(os.path.expanduser('~/.kaggle'), exist_ok=True)
with open(os.path.expanduser('~/.kaggle/kaggle.json'), 'w') as f:
    json.dump(kaggle_credentials, f)
os.chmod(os.path.expanduser('~/.kaggle/kaggle.json'), 0o600)

download_path = kagglehub.dataset_download('datasetdense169/datasetmangokent')
dataset_path  = os.path.join(download_path, 'DatasetV2_Roboflow')
train_dir = os.path.join(dataset_path, 'train')
val_dir   = os.path.join(dataset_path, 'valid')
test_dir  = os.path.join(dataset_path, 'test')

for split, path in [('train', train_dir), ('valid', val_dir), ('test', test_dir)]:
    if os.path.exists(path):
        clases = sorted([d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))])
        total  = sum(len([f for f in os.listdir(os.path.join(path, c))
                          if f.lower().endswith(('.jpg','.jpeg','.png'))]) for c in clases)
        print(f'  ✓ {split:6s}: {total:>5} imgs | clases: {clases}')
    else:
        print(f'  ✗ {split} NO encontrado')
# Out:
# Using Colab cache for faster access to the 'datasetmangokent' dataset.
#   ✓ train :  1032 imgs | clases: ['Defectuoso', 'Sanos']
#   ✓ valid :   239 imgs | clases: ['Defectuoso', 'Sanos']
#   ✓ test  :   316 imgs | clases: ['Defectuoso', 'Sanos']

# %%
# ─── Resultados de este experimento ─────────────────────────────────
RESULTS_TABLE = []  # tabla local para este experimento
print('✅ EXP 37 — BS64_DU128_LR1e4 — Notebook individual')
print('   Criterio de selección: F1-Score weighted en validación')
# Out:
# ✅ EXP 37 — BS64_DU128_LR1e4 — Notebook individual
#    Criterio de selección: F1-Score weighted en validación

# %%
# ─── Callback: Mejor modelo por F1-Score ────────────────────────────────
class BestF1Checkpoint(Callback):
    def __init__(self, val_ds, ckpt_path, verbose=1):
        super().__init__()
        self.val_ds    = val_ds
        self.ckpt_path = ckpt_path
        self.best_f1   = -1.0
        self.best_epoch = 0
        self.verbose   = verbose
        self.f1_history = []

    def on_epoch_end(self, epoch, logs=None):
        y_true, y_pred = [], []
        for x_batch, y_batch in self.val_ds:
            preds = self.model.predict(x_batch, verbose=0)
            y_true.extend(y_batch.numpy().flatten().astype(int))
            y_pred.extend((preds.flatten() > 0.5).astype(int))
        current_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
        self.f1_history.append(current_f1)
        if self.verbose:
            print(f'  val_f1_weighted: {current_f1:.4f}', end='')
        if current_f1 > self.best_f1:
            self.best_f1    = current_f1
            self.best_epoch = epoch + 1
            self.model.save_weights(self.ckpt_path)
            if self.verbose:
                print(f' ✅ Nuevo mejor F1 — pesos guardados')
        else:
            if self.verbose:
                print(f' (mejor: {self.best_f1:.4f} en época {self.best_epoch})')

    def on_train_end(self, logs=None):
        print(f'\n🏆 Mejor F1 en validación: {self.best_f1:.4f} (época {self.best_epoch})')
        print(f'   Restaurando mejores pesos...')
        self.model.load_weights(self.ckpt_path)
        print('   ✅ Pesos restaurados.')

print('✅ Callback BestF1Checkpoint definido')
# Out:
# ✅ Callback BestF1Checkpoint definido

# %%
# ─── Función de construcción del modelo (Transfer Learning puro) ──────────
def get_optimizer():
    opt = CFG['OPTIMIZER']
    lr  = CFG['LR']
    if   opt == 'Adam'        : return keras.optimizers.Adam(learning_rate=lr)
    elif opt == 'Adamax'      : return keras.optimizers.Adamax(learning_rate=lr)
    elif opt == 'SGD'         : return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    elif opt == 'SGD_Nesterov': return keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True)
    elif opt == 'RMSprop'     : return keras.optimizers.RMSprop(learning_rate=lr)
    else: raise ValueError(f'Optimizador desconocido: {opt}')

def build_model():
    base = DenseNet169(weights='imagenet', include_top=False,
                       input_shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3))
    base.trainable = False  # ← Transfer Learning puro: base CONGELADA

    inputs = keras.Input(shape=(CFG['IMG_SIZE'], CFG['IMG_SIZE'], 3))
    x = base(inputs, training=False)
    x = GlobalAveragePooling2D(name='gap')(x)
    if CFG['BN_HEAD']:
        x = BatchNormalization(name='bn_head')(x)
    x = Dropout(CFG['DROPOUT'], name='drop1')(x)
    x = Dense(CFG['DENSE_UNITS'], activation='relu',
              kernel_regularizer=keras.regularizers.l2(CFG['L2']),
              name='dense_head')(x)
    x = Dropout(CFG['DROPOUT'] * 0.6, name='drop2')(x)
    outputs = Dense(1, activation='sigmoid', name='output')(x)

    model = Model(inputs, outputs, name=f"DenseNet169_TL_EXP{CFG['EXPERIMENT_ID']:02d}")
    model.compile(
        optimizer=get_optimizer(),
        loss='binary_crossentropy',
        metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
    )
    return model

print('✅ Función build_model definida (Transfer Learning puro)')
# Out:
# ✅ Función build_model definida (Transfer Learning puro)

# %%
# ─── Funciones de evaluación ─────────────────────────────────────────────
def evaluar(ds_prep, nombre):
    y_true, y_pred, y_prob = [], [], []
    for imgs, lbls in ds_prep:
        preds = model.predict(imgs, verbose=0)
        y_true.extend(lbls.numpy().flatten())
        y_prob.extend(preds.flatten())
        y_pred.extend((preds > 0.5).astype(int).flatten())
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)
    print(f"{'='*58}")
    print(f'  {nombre}')
    print(f"{'='*58}")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
    eps = 1e-7
    loss = -np.mean(y_true * np.log(y_prob + eps) + (1 - y_true) * np.log(1 - y_prob + eps))
    return y_true, y_pred, loss

def metrics_row(y_t, yp_t, y_v, yp_v, y_te_, yp_te_):
    acc_tr  = accuracy_score(y_t,   yp_t)
    acc_va  = accuracy_score(y_v,   yp_v)
    acc_te  = accuracy_score(y_te_, yp_te_)
    prec_tr = precision_score(y_t,   yp_t,   average='weighted', zero_division=0)
    prec_va = precision_score(y_v,   yp_v,   average='weighted', zero_division=0)
    prec_te = precision_score(y_te_, yp_te_, average='weighted', zero_division=0)
    rec_tr  = recall_score(y_t,   yp_t,   average='weighted', zero_division=0)
    rec_va  = recall_score(y_v,   yp_v,   average='weighted', zero_division=0)
    rec_te  = recall_score(y_te_, yp_te_, average='weighted', zero_division=0)
    f1_tr   = f1_score(y_t,   yp_t,   average='weighted', zero_division=0)
    f1_va   = f1_score(y_v,   yp_v,   average='weighted', zero_division=0)
    f1_te   = f1_score(y_te_, yp_te_, average='weighted', zero_division=0)
    return (acc_tr,acc_va,acc_te), (prec_tr,prec_va,prec_te), \
           (rec_tr,rec_va,rec_te), (f1_tr,f1_va,f1_te)

def plot_cm(y_true, y_pred, title, ax, cmap='Blues'):
    cm_ = confusion_matrix(y_true, y_pred)
    norm = cm_.astype(float) / cm_.sum(axis=1)[:,None]
    ann  = [[f'{v}\n({p:.1%})' for v,p in zip(r,rn)] for r,rn in zip(cm_,norm)]
    sns.heatmap(cm_, annot=ann, fmt='', cmap=cmap, ax=ax,
                xticklabels=class_names, yticklabels=class_names,
                annot_kws={'size':11,'weight':'bold'})
    acc = accuracy_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred, average='weighted')
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel(f'Predicho\nAcc={acc:.4f}  F1={f1:.4f}')
    ax.set_ylabel('Real')

print('✅ Funciones de evaluación definidas')
# Out:
# ✅ Funciones de evaluación definidas

# %%
# ─── Funciones Grad-CAM ──────────────────────────────────────────────────
def get_gradcam_heatmap(img_array, model, last_conv_layer_name='conv5_block32_2_conv'):
    base_model = model.get_layer('densenet169')
    last_conv = base_model.get_layer(last_conv_layer_name)
    base_grad_model = tf.keras.models.Model(
        inputs=base_model.inputs,
        outputs=[last_conv.output, base_model.output]
    )
    img_var = tf.Variable(tf.cast(img_array, tf.float32))
    with tf.GradientTape() as tape:
        conv_outputs, base_out = base_grad_model(img_var, training=False)
        x = base_out
        for lname in ['gap', 'bn_head', 'drop1', 'dense_head', 'drop2', 'output']:
            try:
                lyr = model.get_layer(lname)
                x = lyr(x, training=False)
            except Exception:
                pass
        loss = x[:, 0]
    grads        = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap      = conv_outputs[0] @ pooled_grads[..., tf.newaxis]
    heatmap      = tf.squeeze(heatmap)
    heatmap      = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-8)
    return heatmap.numpy()

def overlay_gradcam(original_img, heatmap, alpha=0.4):
    heatmap_resized = np.array(
        tf.image.resize(heatmap[..., np.newaxis],
                        (original_img.shape[0], original_img.shape[1]))
    ).squeeze()
    heatmap_uint8 = np.uint8(255 * heatmap_resized)
    jet_colors    = cm.get_cmap('jet')(np.arange(256))[:, :3]
    jet_heatmap   = jet_colors[heatmap_uint8]
    jet_heatmap   = np.uint8(jet_heatmap * 255)
    superimposed  = jet_heatmap * alpha + original_img * (1 - alpha)
    return np.uint8(superimposed)

print('✅ Funciones Grad-CAM definidas')
# Out:
# ✅ Funciones Grad-CAM definidas

# %%
# ─── EXP 37: BS64_DU128_LR1e4 ─────────────────────────────────────────────
CFG = {
    'EXPERIMENT_ID'  : 37,
    'EXPERIMENT_NAME': 'BS64_DU128_LR1e4',
    'DESCRIPCION'    : 'BS grande + DU grande + LR bajo',

    # ── Rutas ──────────────────────────────────────────────────────
    'DATASET_VERSION': 'DatasetV3_Roboflow',

    # ── Imágenes ───────────────────────────────────────────────────
    'IMG_SIZE'  : 224,
    'BATCH_SIZE': 64,
    'SEED'      : 42,

    # ── Entrenamiento ──────────────────────────────────────────────
    'EPOCHS'    : 50,
    'LR'        : 0.0001,
    'OPTIMIZER' : 'Adam',
    'PATIENCE'  : 10,
    'RLR_FACTOR': 0.5,

    # ── Arquitectura del head ──────────────────────────────────────
    'DENSE_UNITS': 128,
    'DROPOUT'    : 0.5,
    'L2'         : 0.0001,
    'BN_HEAD'    : True,

    # ── Grad-CAM ──────────────────────────────────────────────────
    'GRADCAM_SAMPLES': 8,
    'GRADCAM_ALPHA'  : 0.4,
}

tf.random.set_seed(CFG['SEED'])
np.random.seed(CFG['SEED'])
os.makedirs('checkpoints', exist_ok=True)
os.makedirs('resultados',  exist_ok=True)

print('\n📋 CONFIGURACIÓN — EXP 37: BS64_DU128_LR1e4')
for k, v in CFG.items():
    print(f'  {k:<20}: {v}')
# Out:
# 📋 CONFIGURACIÓN — EXP 37: BS64_DU128_LR1e4
#   EXPERIMENT_ID       : 37
#   EXPERIMENT_NAME     : BS64_DU128_LR1e4
#   DESCRIPCION         : BS grande + DU grande + LR bajo
#   DATASET_VERSION     : DatasetV3_Roboflow
#   IMG_SIZE            : 224
#   BATCH_SIZE          : 64
#   SEED                : 42
#   EPOCHS              : 50
#   LR                  : 0.0001
#   OPTIMIZER           : Adam
#   PATIENCE            : 10
#   RLR_FACTOR          : 0.5
#   DENSE_UNITS         : 128
#   DROPOUT             : 0.5
#   L2                  : 0.0001
#   BN_HEAD             : True
#   GRADCAM_SAMPLES     : 8
#   GRADCAM_ALPHA       : 0.4

# %%
# ─── EXP 37: Carga y preprocesamiento ────────────────────────────
IMG  = CFG['IMG_SIZE']
BS   = CFG['BATCH_SIZE']
SEED = CFG['SEED']

train_ds_raw = tf.keras.utils.image_dataset_from_directory(
    train_dir, labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=True, seed=SEED)
val_ds_raw = tf.keras.utils.image_dataset_from_directory(
    val_dir,   labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=False)
test_ds_raw = tf.keras.utils.image_dataset_from_directory(
    test_dir,  labels='inferred', label_mode='binary',
    image_size=(IMG, IMG), batch_size=BS, shuffle=False)

class_names = train_ds_raw.class_names
preprocess_fn = tf.keras.applications.densenet.preprocess_input

def prepare(ds):
    ds = ds.map(lambda x, y: (preprocess_fn(x), y),
                num_parallel_calls=tf.data.AUTOTUNE)
    return ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

train_ds = prepare(train_ds_raw)
val_ds   = prepare(val_ds_raw)
test_ds  = prepare(test_ds_raw)

y_all = np.concatenate([y.numpy().flatten() for _, y in train_ds_raw])
cw    = class_weight.compute_class_weight('balanced', classes=np.unique(y_all), y=y_all)
class_weights_dict = dict(enumerate(cw))
print(f'Clases: {class_names}')
print(f'Pesos: { {class_names[k]: round(v,3) for k,v in class_weights_dict.items()} }')
# Out:
# Found 1032 files belonging to 2 classes.
# Found 239 files belonging to 2 classes.
# Found 316 files belonging to 2 classes.
# Clases: ['Defectuoso', 'Sanos']
# Pesos: {'Defectuoso': np.float64(1.008), 'Sanos': np.float64(0.992)}

# %%
# ─── EXP 37: Construcción del modelo ─────────────────────────────
model = build_model()
trainable = sum(tf.size(w).numpy() for w in model.trainable_weights)
total     = sum(tf.size(w).numpy() for w in model.weights)
print(f'Parámetros entrenables: {trainable:,} / {total:,} ({100*trainable/total:.2f}%)')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Parámetros entrenables: 216,577 / 12,862,785 (1.68%)

# %%
# ─── EXP 37: Entrenamiento ────────────────────────────────────────
exp_name  = f"EXP{CFG['EXPERIMENT_ID']:02d}_{CFG['EXPERIMENT_NAME']}"
ckpt_path = f"checkpoints/best_{exp_name}.weights.h5"

f1_callback = BestF1Checkpoint(val_ds, ckpt_path, verbose=1)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=CFG['PATIENCE'],
                  restore_best_weights=False, verbose=1),
    f1_callback,
    ReduceLROnPlateau(monitor='val_loss', factor=CFG['RLR_FACTOR'],
                      patience=4, min_lr=1e-8, verbose=1),
    CSVLogger(f"resultados/log_{exp_name}.csv", append=False),
]

print(f'\n=== EXPERIMENTO {CFG["EXPERIMENT_ID"]:02d}: {CFG["EXPERIMENT_NAME"]} ===')
print(f'Desc: {CFG["DESCRIPCION"]}\n')

history = model.fit(
    train_ds, epochs=CFG['EPOCHS'],
    validation_data=val_ds,
    callbacks=callbacks,
    class_weight=class_weights_dict,
    verbose=1
)

print(f'\n{"="*55}')
print(f'🏆 MEJOR ÉPOCA (F1): {f1_callback.best_epoch}')
print(f'   Mejor Val F1      : {f1_callback.best_f1:.4f}')
print(f'{"="*55}')
# Out:
# === EXPERIMENTO 37: BS64_DU128_LR1e4 ===
# Desc: BS grande + DU grande + LR bajo
#
# Epoch 1/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6110 - loss: 0.7276 - precision: 0.6099 - recall: 0.6215     val_f1_weighted: 0.7949 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - accuracy: 0.6793 - loss: 0.6346 - precision: 0.6734 - recall: 0.7058 - val_accuracy: 0.7950 - val_loss: 0.4868 - val_precision: 0.7840 - val_recall: 0.8167 - learning_rate: 1.0000e-04
# Epoch 2/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8062 - loss: 0.4763 - precision: 0.7856 - recall: 0.8455  val_f1_weighted: 0.8030 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 346ms/step - accuracy: 0.8207 - loss: 0.4576 - precision: 0.7863 - recall: 0.8846 - val_accuracy: 0.8033 - val_loss: 0.4423 - val_precision: 0.7829 - val_recall: 0.8417 - learning_rate: 1.0000e-04
# Epoch 3/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8596 - loss: 0.3889 - precision: 0.8330 - recall: 0.9025  val_f1_weighted: 0.8155 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 339ms/step - accuracy: 0.8566 - loss: 0.3970 - precision: 0.8218 - recall: 0.9135 - val_accuracy: 0.8159 - val_loss: 0.4199 - val_precision: 0.7923 - val_recall: 0.8583 - learning_rate: 1.0000e-04
# Epoch 4/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8724 - loss: 0.3526 - precision: 0.8249 - recall: 0.9472  val_f1_weighted: 0.8363 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 389ms/step - accuracy: 0.8614 - loss: 0.3767 - precision: 0.8168 - recall: 0.9346 - val_accuracy: 0.8368 - val_loss: 0.4019 - val_precision: 0.8045 - val_recall: 0.8917 - learning_rate: 1.0000e-04
# Epoch 5/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8830 - loss: 0.3435 - precision: 0.8393 - recall: 0.9488  val_f1_weighted: 0.8488 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 347ms/step - accuracy: 0.8789 - loss: 0.3427 - precision: 0.8308 - recall: 0.9538 - val_accuracy: 0.8494 - val_loss: 0.3849 - val_precision: 0.8134 - val_recall: 0.9083 - learning_rate: 1.0000e-04
# Epoch 6/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8813 - loss: 0.3301 - precision: 0.8294 - recall: 0.9613  val_f1_weighted: 0.8572 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 357ms/step - accuracy: 0.8847 - loss: 0.3348 - precision: 0.8336 - recall: 0.9635 - val_accuracy: 0.8577 - val_loss: 0.3714 - val_precision: 0.8209 - val_recall: 0.9167 - learning_rate: 1.0000e-04
# Epoch 7/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8934 - loss: 0.3138 - precision: 0.8433 - recall: 0.9677  val_f1_weighted: 0.8571 (mejor: 0.8572 en época 6)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - accuracy: 0.8876 - loss: 0.3298 - precision: 0.8367 - recall: 0.9654 - val_accuracy: 0.8577 - val_loss: 0.3588 - val_precision: 0.8162 - val_recall: 0.9250 - learning_rate: 1.0000e-04
# Epoch 8/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9035 - loss: 0.2793 - precision: 0.8515 - recall: 0.9787  val_f1_weighted: 0.8653 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 389ms/step - accuracy: 0.8953 - loss: 0.3019 - precision: 0.8433 - recall: 0.9731 - val_accuracy: 0.8661 - val_loss: 0.3471 - val_precision: 0.8188 - val_recall: 0.9417 - learning_rate: 1.0000e-04
# Epoch 9/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8983 - loss: 0.2932 - precision: 0.8487 - recall: 0.9705  val_f1_weighted: 0.8735 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - accuracy: 0.8866 - loss: 0.3146 - precision: 0.8375 - recall: 0.9615 - val_accuracy: 0.8745 - val_loss: 0.3367 - val_precision: 0.8214 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 10/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8968 - loss: 0.2787 - precision: 0.8519 - recall: 0.9619  val_f1_weighted: 0.8735 (mejor: 0.8735 en época 9)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - accuracy: 0.8953 - loss: 0.2900 - precision: 0.8503 - recall: 0.9615 - val_accuracy: 0.8745 - val_loss: 0.3281 - val_precision: 0.8214 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 11/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9108 - loss: 0.2456 - precision: 0.8632 - recall: 0.9770  val_f1_weighted: 0.8735 (mejor: 0.8735 en época 9)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.9041 - loss: 0.2663 - precision: 0.8574 - recall: 0.9712 - val_accuracy: 0.8745 - val_loss: 0.3209 - val_precision: 0.8214 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 12/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9017 - loss: 0.2544 - precision: 0.8545 - recall: 0.9695  val_f1_weighted: 0.8777 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - accuracy: 0.8983 - loss: 0.2677 - precision: 0.8511 - recall: 0.9673 - val_accuracy: 0.8787 - val_loss: 0.3141 - val_precision: 0.8227 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 13/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9072 - loss: 0.2512 - precision: 0.8617 - recall: 0.9713  val_f1_weighted: 0.8777 (mejor: 0.8777 en época 12)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.8934 - loss: 0.2688 - precision: 0.8498 - recall: 0.9577 - val_accuracy: 0.8787 - val_loss: 0.3088 - val_precision: 0.8227 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 14/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9102 - loss: 0.2346 - precision: 0.8624 - recall: 0.9768  val_f1_weighted: 0.8818 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 373ms/step - accuracy: 0.9041 - loss: 0.2477 - precision: 0.8586 - recall: 0.9692 - val_accuracy: 0.8828 - val_loss: 0.3026 - val_precision: 0.8239 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 15/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9183 - loss: 0.2465 - precision: 0.8703 - recall: 0.9839  val_f1_weighted: 0.8818 (mejor: 0.8818 en época 14)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9070 - loss: 0.2615 - precision: 0.8630 - recall: 0.9692 - val_accuracy: 0.8828 - val_loss: 0.2969 - val_precision: 0.8239 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 16/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9156 - loss: 0.2365 - precision: 0.8749 - recall: 0.9710  val_f1_weighted: 0.8818 (mejor: 0.8818 en época 14)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9060 - loss: 0.2532 - precision: 0.8603 - recall: 0.9712 - val_accuracy: 0.8828 - val_loss: 0.2926 - val_precision: 0.8239 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 17/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9148 - loss: 0.2254 - precision: 0.8742 - recall: 0.9701  val_f1_weighted: 0.8818 (mejor: 0.8818 en época 14)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.9060 - loss: 0.2438 - precision: 0.8678 - recall: 0.9596 - val_accuracy: 0.8828 - val_loss: 0.2908 - val_precision: 0.8239 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 18/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9131 - loss: 0.2272 - precision: 0.8739 - recall: 0.9661  val_f1_weighted: 0.8818 (mejor: 0.8818 en época 14)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.9060 - loss: 0.2455 - precision: 0.8730 - recall: 0.9519 - val_accuracy: 0.8828 - val_loss: 0.2877 - val_precision: 0.8239 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 19/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9250 - loss: 0.2147 - precision: 0.8869 - recall: 0.9753  val_f1_weighted: 0.8818 (mejor: 0.8818 en época 14)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - accuracy: 0.9176 - loss: 0.2269 - precision: 0.8769 - recall: 0.9731 - val_accuracy: 0.8828 - val_loss: 0.2853 - val_precision: 0.8239 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 20/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9196 - loss: 0.2185 - precision: 0.8814 - recall: 0.9707  val_f1_weighted: 0.8947 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 394ms/step - accuracy: 0.9138 - loss: 0.2327 - precision: 0.8696 - recall: 0.9750 - val_accuracy: 0.8954 - val_loss: 0.2818 - val_precision: 0.8417 - val_recall: 0.9750 - learning_rate: 1.0000e-04
# Epoch 21/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9377 - loss: 0.2043 - precision: 0.8980 - recall: 0.9884  val_f1_weighted: 0.8906 (mejor: 0.8947 en época 20)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9205 - loss: 0.2250 - precision: 0.8789 - recall: 0.9769 - val_accuracy: 0.8912 - val_loss: 0.2801 - val_precision: 0.8406 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 22/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9294 - loss: 0.2013 - precision: 0.8925 - recall: 0.9769  val_f1_weighted: 0.8948 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.9196 - loss: 0.2187 - precision: 0.8854 - recall: 0.9654 - val_accuracy: 0.8954 - val_loss: 0.2779 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 23/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9275 - loss: 0.2027 - precision: 0.8866 - recall: 0.9814  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 22)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.9176 - loss: 0.2141 - precision: 0.8769 - recall: 0.9731 - val_accuracy: 0.8954 - val_loss: 0.2764 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 24/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9239 - loss: 0.1898 - precision: 0.8885 - recall: 0.9704  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 22)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - accuracy: 0.9186 - loss: 0.2101 - precision: 0.8865 - recall: 0.9615 - val_accuracy: 0.8954 - val_loss: 0.2750 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 25/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9334 - loss: 0.1900 - precision: 0.9001 - recall: 0.9754  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 22)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.9196 - loss: 0.2181 - precision: 0.8867 - recall: 0.9635 - val_accuracy: 0.8954 - val_loss: 0.2732 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 26/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9362 - loss: 0.1823 - precision: 0.9000 - recall: 0.9819  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 22)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.9293 - loss: 0.1999 - precision: 0.8928 - recall: 0.9769 - val_accuracy: 0.8954 - val_loss: 0.2716 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 27/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9389 - loss: 0.1891 - precision: 0.9055 - recall: 0.9804  val_f1_weighted: 0.8948 (mejor: 0.8948 en época 22)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - accuracy: 0.9264 - loss: 0.2060 - precision: 0.8922 - recall: 0.9712 - val_accuracy: 0.8954 - val_loss: 0.2716 - val_precision: 0.8467 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 28/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9392 - loss: 0.1839 - precision: 0.9094 - recall: 0.9759  val_f1_weighted: 0.9034 ✅ Nuevo mejor F1 — pesos guardados
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 368ms/step - accuracy: 0.9273 - loss: 0.1969 - precision: 0.8952 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2720 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 29/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9289 - loss: 0.1737 - precision: 0.8932 - recall: 0.9747  val_f1_weighted: 0.9034 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 377ms/step - accuracy: 0.9225 - loss: 0.1907 - precision: 0.8873 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2730 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 1.0000e-04
# Epoch 30/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9242 - loss: 0.1788 - precision: 0.8812 - recall: 0.9812  val_f1_weighted: 0.8992 (mejor: 0.9034 en época 28)
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.9147 - loss: 0.2062 - precision: 0.8750 - recall: 0.9692 - val_accuracy: 0.8996 - val_loss: 0.2724 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 1.0000e-04
# Epoch 31/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9338 - loss: 0.1784 - precision: 0.8984 - recall: 0.9790  val_f1_weighted: 0.8992 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - accuracy: 0.9254 - loss: 0.1979 - precision: 0.8920 - recall: 0.9692 - val_accuracy: 0.8996 - val_loss: 0.2723 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 32/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9331 - loss: 0.1662 - precision: 0.8989 - recall: 0.9765  val_f1_weighted: 0.8992 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9254 - loss: 0.1846 - precision: 0.8907 - recall: 0.9712 - val_accuracy: 0.8996 - val_loss: 0.2732 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 33/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9461 - loss: 0.1595 - precision: 0.9067 - recall: 0.9950  val_f1_weighted: 0.8992 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9380 - loss: 0.1784 - precision: 0.8972 - recall: 0.9904 - val_accuracy: 0.8996 - val_loss: 0.2722 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 34/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9389 - loss: 0.1629 - precision: 0.9002 - recall: 0.9877  val_f1_weighted: 0.8992 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 0.9331 - loss: 0.1772 - precision: 0.8949 - recall: 0.9827 - val_accuracy: 0.8996 - val_loss: 0.2712 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 35/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9382 - loss: 0.1736 - precision: 0.9041 - recall: 0.9808  val_f1_weighted: 0.8992 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.9312 - loss: 0.1900 - precision: 0.9016 - recall: 0.9692 - val_accuracy: 0.8996 - val_loss: 0.2705 - val_precision: 0.8582 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 36/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9363 - loss: 0.1731 - precision: 0.9101 - recall: 0.9693  val_f1_weighted: 0.8950 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - accuracy: 0.9264 - loss: 0.1906 - precision: 0.8936 - recall: 0.9692 - val_accuracy: 0.8954 - val_loss: 0.2708 - val_precision: 0.8519 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 37/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9360 - loss: 0.1744 - precision: 0.9114 - recall: 0.9665  val_f1_weighted: 0.8991 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.9264 - loss: 0.1911 - precision: 0.9007 - recall: 0.9596 - val_accuracy: 0.8996 - val_loss: 0.2708 - val_precision: 0.8529 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 38/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9385 - loss: 0.1739 - precision: 0.9052 - recall: 0.9802  val_f1_weighted: 0.9034 (mejor: 0.9034 en época 28)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - accuracy: 0.9341 - loss: 0.1901 - precision: 0.9007 - recall: 0.9769 - val_accuracy: 0.9038 - val_loss: 0.2706 - val_precision: 0.8593 - val_recall: 0.9667 - learning_rate: 5.0000e-05
# Epoch 39/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9408 - loss: 0.1673 - precision: 0.9039 - recall: 0.9869  val_f1_weighted: 0.9035 ✅ Nuevo mejor F1 — pesos guardados
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 382ms/step - accuracy: 0.9254 - loss: 0.1895 - precision: 0.8907 - recall: 0.9712 - val_accuracy: 0.9038 - val_loss: 0.2705 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 5.0000e-05
# Epoch 40/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9388 - loss: 0.1658 - precision: 0.9131 - recall: 0.9705  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 280ms/step - accuracy: 0.9341 - loss: 0.1746 - precision: 0.9065 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2706 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 41/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9461 - loss: 0.1552 - precision: 0.9186 - recall: 0.9795  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - accuracy: 0.9428 - loss: 0.1709 - precision: 0.9168 - recall: 0.9750 - val_accuracy: 0.9038 - val_loss: 0.2711 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 42/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9275 - loss: 0.1785 - precision: 0.9038 - recall: 0.9575  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.9254 - loss: 0.1888 - precision: 0.8977 - recall: 0.9615 - val_accuracy: 0.9038 - val_loss: 0.2706 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 43/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9425 - loss: 0.1750 - precision: 0.9094 - recall: 0.9834  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.9302 - loss: 0.1881 - precision: 0.9014 - recall: 0.9673 - val_accuracy: 0.9038 - val_loss: 0.2702 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 44/50
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9426 - loss: 0.1699 - precision: 0.9238 - recall: 0.9666  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9283 - loss: 0.1898 - precision: 0.8996 - recall: 0.9654 - val_accuracy: 0.9038 - val_loss: 0.2701 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 45/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9281 - loss: 0.1806 - precision: 0.9006 - recall: 0.9631  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - accuracy: 0.9273 - loss: 0.1888 - precision: 0.8980 - recall: 0.9654 - val_accuracy: 0.9038 - val_loss: 0.2693 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 46/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9385 - loss: 0.1659 - precision: 0.9059 - recall: 0.9791  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - accuracy: 0.9302 - loss: 0.1884 - precision: 0.9043 - recall: 0.9635 - val_accuracy: 0.9038 - val_loss: 0.2691 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 47/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9471 - loss: 0.1671 - precision: 0.9202 - recall: 0.9797  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 287ms/step - accuracy: 0.9331 - loss: 0.1854 - precision: 0.9048 - recall: 0.9692 - val_accuracy: 0.9038 - val_loss: 0.2694 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 48/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9500 - loss: 0.1508 - precision: 0.9170 - recall: 0.9897  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.9390 - loss: 0.1778 - precision: 0.9088 - recall: 0.9769 - val_accuracy: 0.9038 - val_loss: 0.2697 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 49/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9414 - loss: 0.1664 - precision: 0.9134 - recall: 0.9759  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 291ms/step - accuracy: 0.9380 - loss: 0.1747 - precision: 0.9086 - recall: 0.9750 - val_accuracy: 0.9038 - val_loss: 0.2699 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
# Epoch 50/50
# 16/17 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9320 - loss: 0.1675 - precision: 0.8994 - recall: 0.9736  val_f1_weighted: 0.9035 (mejor: 0.9035 en época 39)
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - accuracy: 0.9293 - loss: 0.1763 - precision: 0.8956 - recall: 0.9731 - val_accuracy: 0.9038 - val_loss: 0.2701 - val_precision: 0.8647 - val_recall: 0.9583 - learning_rate: 2.5000e-05
#
# 🏆 Mejor F1 en validación: 0.9035 (época 39)
#    Restaurando mejores pesos...
#    ✅ Pesos restaurados.
#
# =======================================================
# 🏆 MEJOR ÉPOCA (F1): 39
#    Mejor Val F1      : 0.9035
# =======================================================

# %%
# ─── EXP 37: Curvas de entrenamiento ──────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()
metrics_plot = [
    ('accuracy','val_accuracy','Accuracy'),
    ('loss','val_loss','Loss'),
    ('precision','val_precision','Precision'),
    ('recall','val_recall','Recall'),
]
for ax, (tk, vk, lbl) in zip(axes, metrics_plot):
    ep = range(1, len(history.history[tk])+1)
    ax.plot(ep, history.history[tk], 'b-o', ms=4, label='Train')
    ax.plot(ep, history.history[vk], 'r-o', ms=4, label='Val')
    be = int(np.argmin(history.history[vk]) if 'loss' in vk else np.argmax(history.history[vk]))
    ax.axvline(be+1, color='green', ls='--', alpha=0.7, label=f'Mejor ({be+1})')
    ax.set_title(lbl, fontweight='bold')
    ax.set_xlabel('Época'); ax.set_ylabel(lbl)
    ax.legend(); ax.grid(True, alpha=0.3)

fig2, ax2 = plt.subplots(figsize=(8, 4))
ax2.plot(range(1, len(f1_callback.f1_history)+1), f1_callback.f1_history, 'g-o', ms=4)
ax2.axvline(f1_callback.best_epoch, color='red', ls='--',
            label=f'Mejor F1={f1_callback.best_f1:.4f} (época {f1_callback.best_epoch})')
ax2.set_title('Val F1-Score Weighted por Época', fontweight='bold')
ax2.set_xlabel('Época'); ax2.set_ylabel('F1-Score')
ax2.legend(); ax2.grid(True, alpha=0.3)
fig2.tight_layout()
fig2.savefig(f'resultados/f1_curve_{exp_name}.png', dpi=130, bbox_inches='tight')

title = f"EXP {CFG['EXPERIMENT_ID']:02d} — {CFG['EXPERIMENT_NAME']}"
fig.suptitle(f'Curvas — {title}', fontsize=13, fontweight='bold')
fig.tight_layout()
fig.savefig(f'resultados/curvas_{exp_name}.png', dpi=130, bbox_inches='tight')
plt.show()

# %%
# ─── EXP 37: Evaluación Train / Valid / Test ──────────────────────
y_tr, yp_tr, loss_tr = evaluar(train_ds, 'ENTRENAMIENTO')
y_va, yp_va, loss_va = evaluar(val_ds,   'VALIDACIÓN')
y_te, yp_te, loss_te = evaluar(test_ds,  'PRUEBA (Test) ★')

(acc_tr,acc_va,acc_te), (prec_tr,prec_va,prec_te), \
(rec_tr,rec_va,rec_te), (f1_tr,f1_va,f1_te) = metrics_row(
    y_tr, yp_tr, y_va, yp_va, y_te, yp_te)

print('\n' + '='*65)
print(f'  📊 EXP 37 — MÉTRICAS GLOBALES')
print('='*65)
print(f"{'Métrica':<28} {'Train':>10} {'Validación':>12} {'Test':>10}")
print('-'*65)
rows_exp = [
    ('Exactitud (Accuracy)',  acc_tr,  acc_va,  acc_te),
    ('Pérdida (BCE Loss)',    loss_tr, loss_va, loss_te),
    ('Precisión (Weighted)', prec_tr, prec_va, prec_te),
    ('Recall (Weighted)',    rec_tr,  rec_va,  rec_te),
    ('F1-Score (Weighted)',  f1_tr,   f1_va,   f1_te),
]
for label, tr, va, te in rows_exp:
    print(f"  {label:<26} {tr:>10.4f} {va:>12.4f} {te:>10.4f}")
print('='*65)
print(f"  {'★ Mejor época (F1)':<26} {f1_callback.best_epoch:>10}")
print(f"  {'★ Mejor val_f1':<26} {f1_callback.best_f1:>10.4f}")
print('='*65)

# Guardar resumen en tabla global
RESULTS_TABLE.append({
    'EXP': f'EXP37',
    'NOMBRE': 'BS64_DU128_LR1e4',
    'LR': 0.0001, 'BS': 64, 'DU': 128,
    'OPT': 'Adam', 'DROP': 0.5, 'L2': 0.0001, 'BN': True,
    'val_f1': round(f1_callback.best_f1, 4),
    'test_f1': round(f1_te, 4),
    'test_acc': round(acc_te, 4),
    'test_prec': round(prec_te, 4),
    'test_rec': round(rec_te, 4),
    'best_epoch': f1_callback.best_epoch,
})
# Out:
# ==========================================================
#   ENTRENAMIENTO
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9875    0.9277    0.9567       512
#        Sanos     0.9328    0.9885    0.9599       520
#
#     accuracy                         0.9583      1032
#    macro avg     0.9602    0.9581    0.9583      1032
# weighted avg     0.9600    0.9583    0.9583      1032
#
# ==========================================================
#   VALIDACIÓN
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9528    0.8487    0.8978       119
#        Sanos     0.8647    0.9583    0.9091       120
#
#     accuracy                         0.9038       239
#    macro avg     0.9087    0.9035    0.9034       239
# weighted avg     0.9086    0.9038    0.9035       239
#
# ==========================================================
#   PRUEBA (Test) ★
# ==========================================================
#               precision    recall  f1-score   support
#
#   Defectuoso     0.9932    0.8896    0.9385       163
#        Sanos     0.8941    0.9935    0.9412       153
#
#     accuracy                         0.9399       316
#    macro avg     0.9436    0.9415    0.9398       316
# weighted avg     0.9452    0.9399    0.9398       316
#
#
# =================================================================
#   📊 EXP 37 — MÉTRICAS GLOBALES
# =================================================================
# Métrica                           Train   Validación       Test
# -----------------------------------------------------------------
#   Exactitud (Accuracy)           0.9583       0.9038     0.9399
#   Pérdida (BCE Loss)             0.1205       0.2539     0.1795
#   Precisión (Weighted)           0.9600       0.9086     0.9452
#   Recall (Weighted)              0.9583       0.9038     0.9399
#   F1-Score (Weighted)            0.9583       0.9035     0.9398
# =================================================================
#   ★ Mejor época (F1)                 39
#   ★ Mejor val_f1                 0.9035
# =================================================================

# %%
# ─── EXP 37: Matrices de confusión ────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(20, 6))
plot_cm(y_tr, yp_tr, 'Train',   axes[0], 'Blues')
plot_cm(y_va, yp_va, 'Valid',   axes[1], 'Greens')
plot_cm(y_te, yp_te, 'Test ★', axes[2], 'Oranges')
plt.suptitle(f"Matrices de Confusión — EXP 37",
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(f'resultados/cm_{exp_name}.png', dpi=130, bbox_inches='tight')
plt.show()

# %%
# ─── EXP 37: Grad-CAM ─────────────────────────────────────────────
LAST_CONV = 'conv5_block32_2_conv'
N = CFG['GRADCAM_SAMPLES']
samples = {0: [], 1: []}
for imgs_raw, lbls in test_ds_raw:
    imgs_prep_batch = preprocess_fn(tf.cast(imgs_raw, tf.float32))
    for img_raw, img_prep, lbl in zip(imgs_raw.numpy(), imgs_prep_batch.numpy(), lbls.numpy()):
        c = int(lbl)
        if len(samples[c]) < N:
            samples[c].append((img_raw.astype(np.uint8), img_prep))
    if all(len(v) >= N for v in samples.values()):
        break

ALPHA = CFG['GRADCAM_ALPHA']
for clase_idx, clase_name in enumerate(class_names):
    imgs_list = samples[clase_idx]
    n_cols = min(N, len(imgs_list))
    fig, axes = plt.subplots(2, n_cols, figsize=(3 * n_cols, 7))
    fig.suptitle(f'Grad-CAM — Clase: {clase_name}  |  EXP 37',
                 fontsize=13, fontweight='bold')
    for col, (img_orig, img_prep) in enumerate(imgs_list[:n_cols]):
        inp = img_prep[np.newaxis, ...].astype(np.float32)
        heatmap = get_gradcam_heatmap(inp, model, LAST_CONV)
        overlay = overlay_gradcam(img_orig, heatmap, alpha=ALPHA)
        prob    = model.predict(inp, verbose=0)[0][0]
        pred_name = class_names[int(prob > 0.5)]
        axes[0, col].imshow(img_orig)
        axes[0, col].set_title(f'Original\nProb={prob:.2f}', fontsize=8)
        axes[0, col].axis('off')
        axes[1, col].imshow(overlay)
        axes[1, col].set_title(f'Grad-CAM\nPred: {pred_name}', fontsize=8)
        axes[1, col].axis('off')
    plt.tight_layout()
    fname = f'resultados/gradcam_{exp_name}_{clase_name}.png'
    plt.savefig(fname, dpi=130, bbox_inches='tight')
    plt.show()
    print(f'  💾 {fname}')
# Out:
#   💾 resultados/gradcam_EXP37_BS64_DU128_LR1e4_Defectuoso.png
#   💾 resultados/gradcam_EXP37_BS64_DU128_LR1e4_Sanos.png

# %%
# ─── Resumen final EXP 37 ──────────────────────────────────────────
if RESULTS_TABLE:
    r = RESULTS_TABLE[0]
    print('\n' + '★'*60)
    print(f'  🏆 RESULTADO — EXP 37: BS64_DU128_LR1e4')
    print('★'*60)
    for k, v in r.items():
        print(f'  {k:<16}: {v}')
    print('★'*60)
    df_exp = pd.DataFrame(RESULTS_TABLE)
    df_exp.to_csv(f'resultados/resumen_EXP37_BS64_DU128_LR1e4.csv', index=False)
    print('\n💾 CSV guardado: resultados/resumen_EXP37_BS64_DU128_LR1e4.csv')
else:
    print('⚠️ RESULTS_TABLE vacía — ejecuta las celdas anteriores primero')
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#   🏆 RESULTADO — EXP 37: BS64_DU128_LR1e4
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#   EXP             : EXP37
#   NOMBRE          : BS64_DU128_LR1e4
#   LR              : 0.0001
#   BS              : 64
#   DU              : 128
#   OPT             : Adam
#   DROP            : 0.5
#   L2              : 0.0001
#   BN              : True
#   val_f1          : 0.9035
#   test_f1         : 0.9398
#   test_acc        : 0.9399
#   test_prec       : 0.9452
#   test_rec        : 0.9399
#   best_epoch      : 39
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
#
# 💾 CSV guardado: resultados/resumen_EXP37_BS64_DU128_LR1e4.csv
